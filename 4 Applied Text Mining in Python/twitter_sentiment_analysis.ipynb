# %% [markdown]
# # Twitter Sentiment Analysis
#
# Here we'll perform a sentiment analysis with collected tweets with the topic *covid*. The pipline consists in connecting to NoSQL MongoDB, collect tweets with Tweepy API, and analyze the tweets.

# %% [markdown]
# # 1. MongoDB
#
# MongoDB is the most well known and used NoSQL database programa, document-oriented (json-like documents with optional schemas). This is why we'll use it here [[1]](https://en.wikipedia.org/wiki/MongoDB).
#
# The procedure here is quite simple.
# Firstly, we'll create a connection to MongoDB, connect to a database through an object, and select a collection to insert our tweets, also through an object.

# %%
from pymongo import MongoClient
from datetime import datetime

# %%
# create client connection with MongoDB
client = MongoClient('localhost', 27017)

# %%
# check out existing databases
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'twitter_db']

# %%
# create object for the selected database "twitter_db"
db = client['twitter_db']

# %%
# if need to create collection
# db.create_collection('tweets')

# %%
# check out existing collection
db.list_collection_names()
# Out:
# ['tweets']

# %%
# create object for the selected collection existing in the selected database through the beforehand
# created object
col = db['tweets']

# %%
# if need to drop database/collection
# client['twitter_db'].drop()
# db.tweet.drop()

# %% [markdown]
# # 2. Tweepy
#
# Now, to connect to the Twitter API and collect the tweets, we'll use *Tweepy*, also one of the most used libraries for such use.
#
# It's API class provides access to the entire twitter RESTful API methods. Each method can accept various parameters and return responses. More about it can be found here [[2]](http://docs.tweepy.org/en/latest/getting_started.html#introduction).

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler, Stream, API
import json

# %%
# Twitter API Keys, always needed to connect to the Twitter API
consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""

# %%
# API Authentication
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
# create listener class to collect tweets and insert them into
# the collection created n MongoDB
class theListener(StreamListener):
    """
    Twitter Listener Class to collect tweets
    """
    
    def on_connect(self):
        print("You're connected to the streaming API")
    
    def on_data(self, data):
        t = json.loads(data)
        tweet = {
        'created_at': t['created_at'],
        'text': t['text'],
        'user_location': t['user']['location'],
                }
        tweetind = col.insert_one(tweet)        # insert the tweets on MongoDB collection
        return True
    
    def on_error(self,status):
        if status == 420:                       # twitter has a limit for continuos accessing
            print('420 error - limited reached')  
            return False
        print(status)

# %%
# instantiate listener and stream
listener = theListener(api=API(wait_on_rate_limit=True))
stream = Stream(auth, listener)

# %%
# keywords for tweet filter
keywords = ['covid']
languages = ['en']

# %%
# here we need to hit the button to stop collection
# apply a "try-except" block since when stop button is hitted
# a KeyboardInterruption error raises, and we don't need to see that

try:
    stream.filter(track=keywords, languages=languages)
except KeyboardInterrupt:
    print('End of Collection')
    pass
# Out:
# You're connected to the streaming API
# End of Collection

# %%
# always disconnect from the API to avoid reaching limit
stream.disconnect()

# %% [markdown]
# # 3. Pandas
#
# Now let's create our dataframe with collected tweets, to ease our way on analyzing them.

# %%
import pandas as pd

# %%
tweets = pd.DataFrame(list(col.find()))

# %%
print('Dataset composed by %s tweets' % tweets.shape[0])
# Out:
# Dataset composed by 1174 tweets

# %%
tweets.head()
# Out:
#                         _id                      created_at  \
# 0  5f591ea4eda4eefcf7671e83  Wed Sep 09 18:27:42 +0000 2020
# 1  5f591ea4eda4eefcf7671e84  Wed Sep 09 18:27:42 +0000 2020
# 2  5f591ea4eda4eefcf7671e85  Wed Sep 09 18:27:42 +0000 2020
# 3  5f591ea4eda4eefcf7671e86  Wed Sep 09 18:27:43 +0000 2020
# 4  5f591ea4eda4eefcf7671e87  Wed Sep 09 18:27:43 +0000 2020
#
#                                                 text         user_location
# 0  RT @DavoHowarth: More people died of suicide t...  Hampshire, England
# 1  What is a "covid secure marshall"? I am seeing...                  None
# 2  RT @mylifeiskara: Colleges and Universities, s...                ♌️♊️♉️
# 3         RT @ShameenYakubu: Y’all seeing this right          Anchorage,AK
# 4  RT @AYARHEP_KENYA: With COVID-19 struggles hav...        Nairobi, Kenya

# %% [markdown]
# # 4. Sentiment Analysis
#
# A sentiment analysis consists in checking out the tweet text and apply different analysis over the words (e.g. lexical or vector) and classify the tweet in positive, neutral, or negative. This is quite useful for several different purposed e.g. check out how candidates of an election are going, or check out about the feedback of a product, etc.
#
# Now definitely one of the best plataforms to work with human language data is the *Natural Language Tool Kit*, which incorporates several corpora (texts) and lexical resources [[3]](http://www.nltk.org/).
#
# For this sentiment analysis, we'll apply different tools, some that need labaled data as training set and use word vector transformations (Naïve Bayes and Support Vector Machine), and others "unlabeled" that directly label data using lexical and previous built-in trained corpus.
#
# Since we have a labeled corpus to use, as explained ahead, we can check how these "unlabeled" algorithms go on that training set.

# %% [markdown]
# ## 4.1. Comparison
#
# Here we'll use a corpus made by Niek Sanders with little more than 5,000 hand-classified tweets [[4]](https://github.com/zfz/twitter_corpus) in order to compare the "unlabeled" algorithms results with the hand-on classifications.

# %%
import nltk

# nltk.download('vader_lexicon')
# nltk.download('movie_reviews')

# %%
corpusFile = pd.read_csv('full-corpus.csv')
print(corpusFile.shape)
corpusFile.head()
# Out:
# (5113, 5)
#    Topic Sentiment             TweetId                       TweetDate  \
# 0  apple  positive  126415614616154112  Tue Oct 18 21:53:25 +0000 2011
# 1  apple  positive  126404574230740992  Tue Oct 18 21:09:33 +0000 2011
# 2  apple  positive  126402758403305474  Tue Oct 18 21:02:20 +0000 2011
# 3  apple  positive  126397179614068736  Tue Oct 18 20:40:10 +0000 2011
# 4  apple  positive  126395626979196928  Tue Oct 18 20:34:00 +0000 2011
#
#                                            TweetText
# 0  Now all @Apple has to do is get swype on the i...
# 1  @Apple will be adding more carrier support to ...
# 2  Hilarious @youtube video - guy does a duet wit...
# 3  @RIM you made it too easy for me to switch to ...
# 4  I just realized that the reason I got into twi...

# %%
# values are imbalanced
corpusFile['Sentiment'].value_counts()
# Out:
# neutral       2333
# irrelevant    1689
# negative       572
# positive       519
# Name: Sentiment, dtype: int64

# %%
# let's downsample so the training set is balanced, and drop irrelevant labels

minimum = corpusFile['Sentiment'].value_counts().min()

def downsample(corpusFile):
    return corpusFile.sample(minimum, random_state=42)
    
gb = corpusFile.groupby(['Sentiment'])
corpus = gb.apply(downsample).reset_index(drop=True)
corpus = corpus[corpus['Sentiment'] != 'irrelevant']

print(corpus.shape)
corpus.head()
# Out:
# (1557, 5)
#          Topic Sentiment             TweetId                       TweetDate  \
# 519    twitter  negative  126881376074076161  Thu Oct 20 04:44:12 +0000 2011
# 520      apple  negative  126251052667375616  Tue Oct 18 10:59:31 +0000 2011
# 521      apple  negative  126014999444467712  Mon Oct 17 19:21:31 +0000 2011
# 522  microsoft  negative  126744130784198656  Wed Oct 19 19:38:50 +0000 2011
# 523    twitter  negative  126869855621218304  Thu Oct 20 03:58:25 +0000 2011
#
#                                              TweetText
# 519  Wtf is a tweet , sounds like tha dam cartoon n...
# 520  #DontBeMadAtMeBecause #Android is by far bette...
# 521  I really hate dealing with the brain dead peop...
# 522  Reader 'Tronman' compares #SteveBallmer to an ...
# 523  #Twitter.... Side Affects include: Procrastina...

# %%
corpus['Sentiment'].value_counts()
# Out:
# positive    519
# neutral     519
# negative    519
# Name: Sentiment, dtype: int64

# %%
# let's label them for comparison
corpus['label'] = 0
for i in range(0, corpus.shape[0]):
    if corpus.iloc[i,1] == 'positive':
        corpus.iloc[i,5] = 1
    elif corpus.iloc[i,1] == 'negative':
        corpus.iloc[i,5] = -1
    elif corpus.iloc[i,1] == 'neutral':
        corpus.iloc[i,5] = 0

# %%
corpus_tweet = corpus['TweetText'].to_list()

# %% [markdown]
# ### 4.1.1. TextBlob
#
# TextBlob is a Python library for processing textual data, which has an API for diving into common natural language processing (NLP) tasks such as part-of-speech tagging, noun phrase extraction, sentiment analysis, classification, translation, and more [[5]](https://textblob.readthedocs.io/en/dev/). In TextBlob, all works like simple Python strings, which simplifies things a lot!
#
# As for sentiment analysis, TextBlob contains two Sentiment Analyzers:
# - *PatternAnalyzer*, based on the pattern library [[6]](https://planspace.org/20150607-textblob_sentiment/https://planspace.org/20150607-textblob_sentiment/)
# - *NaiveBayesAnalyzer* based on NLTK classifier trained on a movie review corpus [[7]](https://textblob.readthedocs.io/en/dev/advanced_usage.html#sentiment-analyzers)
#
# As for the first, it returns a namedtuple containing *polarity* ranging from [-1,1] i.e. negative and positive sentiment, and *subectivity*, randing from [0,1], where 0 is very objective, and 1 is subjective; whereas for the second, it returns a namedtuple in the form *(classification, p_pos, p_neg)*

# %%
from textblob import TextBlob

# %%
from textblob.sentiments import PatternAnalyzer

for tweet in corpus_tweet: 
    print(TextBlob(tweet, analyzer = PatternAnalyzer()).sentiment)
# Out:
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.3, subjectivity=0.75)
# Sentiment(polarity=-0.12000000000000002, subjectivity=0.54)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.25, subjectivity=0.4)
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Sentiment(polarity=-0.3125, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=0.8888888888888888)
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.7)
# Sentiment(polarity=0.2, subjectivity=0.85)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.32159090909090915, subjectivity=0.4636363636363636)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Sentiment(polarity=-0.175, subjectivity=0.4)
# Sentiment(polarity=-0.25, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.19999999999999998, subjectivity=0.3523809523809524)
# Sentiment(polarity=0.24999999999999997, subjectivity=0.8557539682539683)
# Sentiment(polarity=0.11212121212121212, subjectivity=0.21818181818181817)
# Sentiment(polarity=0.24375000000000002, subjectivity=0.475)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=-0.17500000000000002, subjectivity=0.4)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1, subjectivity=0.8)
# Sentiment(polarity=-0.8, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15, subjectivity=0.675)
# Sentiment(polarity=-0.475, subjectivity=0.8)
# Sentiment(polarity=-0.75, subjectivity=1.0)
# Sentiment(polarity=-0.75, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.6)
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.175, subjectivity=0.275)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=-0.4, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.0625, subjectivity=0.1625)
# Sentiment(polarity=0.8, subjectivity=0.6)
# Sentiment(polarity=-0.056666666666666664, subjectivity=0.56)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.1787878787878788, subjectivity=0.4515151515151515)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.0062500000000000056, subjectivity=0.45)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.07500000000000001, subjectivity=0.05)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1, subjectivity=0.3)
# Sentiment(polarity=0.11666666666666665, subjectivity=0.9166666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.6)
# Sentiment(polarity=-0.8999999999999999, subjectivity=0.9)
# Sentiment(polarity=0.25, subjectivity=1.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5571428571428572, subjectivity=0.7285714285714285)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.75)
# Sentiment(polarity=-0.375, subjectivity=0.736111111111111)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=0.35, subjectivity=0.35)
# Sentiment(polarity=0.0, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3621212121212121, subjectivity=0.5515151515151515)
# Sentiment(polarity=-0.19181818181818183, subjectivity=0.6822727272727273)
# Sentiment(polarity=0.1, subjectivity=1.0)
# Sentiment(polarity=-0.07500000000000001, subjectivity=0.05)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.5)
# Sentiment(polarity=0.011111111111111118, subjectivity=0.15555555555555556)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-1.0, subjectivity=0.9)
# Sentiment(polarity=-0.625, subjectivity=0.875)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.033333333333333326, subjectivity=0.47500000000000003)
# Sentiment(polarity=-0.1, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.20454545454545456, subjectivity=0.48484848484848486)
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.7666666666666666)
# Sentiment(polarity=-0.03750000000000002, subjectivity=0.6375)
# Sentiment(polarity=-0.6, subjectivity=0.8)
# Sentiment(polarity=0.0625, subjectivity=0.5)
# Sentiment(polarity=-0.2, subjectivity=0.8)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15, subjectivity=0.8)
# Sentiment(polarity=-0.1, subjectivity=0.30000000000000004)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.16249999999999998, subjectivity=0.825)
# Sentiment(polarity=-0.25, subjectivity=0.4)
# Sentiment(polarity=0.0625, subjectivity=0.55)
# Sentiment(polarity=0.009090909090909094, subjectivity=0.4636363636363636)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=-0.2, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.18787878787878787, subjectivity=0.5515151515151515)
# Sentiment(polarity=0.19318181818181818, subjectivity=0.32727272727272727)
# Sentiment(polarity=0.15625, subjectivity=0.5)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.054999999999999966, subjectivity=0.51)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Sentiment(polarity=-0.5, subjectivity=0.6)
# Sentiment(polarity=-0.2916666666666667, subjectivity=0.5)
# Sentiment(polarity=-0.09999999999999999, subjectivity=0.2)
# Sentiment(polarity=-0.1777777777777778, subjectivity=0.24444444444444446)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=-0.625, subjectivity=0.3)
# Sentiment(polarity=-0.2916666666666667, subjectivity=0.5416666666666666)
# Sentiment(polarity=0.1787878787878788, subjectivity=0.4515151515151515)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.41666666666666663, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# Sentiment(polarity=-0.20000000000000004, subjectivity=0.8000000000000002)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.24285714285714288, subjectivity=0.6438095238095238)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.01237373737373739, subjectivity=0.4404040404040404)
# Sentiment(polarity=0.0, subjectivity=0.55)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.8, subjectivity=0.9)
# Sentiment(polarity=-0.8, subjectivity=0.95)
# Sentiment(polarity=-0.15, subjectivity=0.825)
# Sentiment(polarity=-0.25, subjectivity=0.5)
# Sentiment(polarity=-0.02500000000000001, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.375)
# Sentiment(polarity=0.8, subjectivity=1.0)
# Sentiment(polarity=-0.2, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2333333333333333, subjectivity=0.5333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.10000000000000002, subjectivity=0.762962962962963)
# Sentiment(polarity=-0.3125, subjectivity=0.32499999999999996)
# Sentiment(polarity=0.1, subjectivity=0.6)
# Sentiment(polarity=-0.08787878787878789, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.48828125, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.625, subjectivity=0.5)
# Sentiment(polarity=-1.0, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.125, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.7, subjectivity=0.8)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2222222222222222, subjectivity=0.6444444444444445)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# Sentiment(polarity=-0.25, subjectivity=0.8)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.55, subjectivity=0.65)
# Sentiment(polarity=0.1, subjectivity=0.6000000000000001)
# Sentiment(polarity=-0.3125, subjectivity=0.5)
# Sentiment(polarity=-0.08787878787878789, subjectivity=0.15151515151515152)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.75, subjectivity=0.7833333333333333)
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.625, subjectivity=0.3)
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.75)
# Sentiment(polarity=-1.0, subjectivity=0.9)
# Sentiment(polarity=0.01785714285714285, subjectivity=0.46785714285714286)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.20000000000000004, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.29464285714285704, subjectivity=0.6011904761904762)
# Sentiment(polarity=-0.19272727272727272, subjectivity=0.7309090909090908)
# Sentiment(polarity=0.43333333333333335, subjectivity=0.43333333333333335)
# Sentiment(polarity=-0.2916666666666667, subjectivity=0.5416666666666666)
# Sentiment(polarity=0.0625, subjectivity=0.44999999999999996)
# Sentiment(polarity=0.38, subjectivity=0.49000000000000005)
# Sentiment(polarity=-0.5333333333333333, subjectivity=0.8888888888888888)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3, subjectivity=0.6)
# Sentiment(polarity=-0.375, subjectivity=0.3)
# Sentiment(polarity=-0.2, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.6, subjectivity=0.7)
# Sentiment(polarity=0.25, subjectivity=0.2)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.4083333333333334)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.16666666666666666, subjectivity=0.5000000000000001)
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.8333333333333334)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.16666666666666666, subjectivity=0.20833333333333334)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.734375, subjectivity=0.6000000000000001)
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.4)
# Sentiment(polarity=0.05833333333333335, subjectivity=0.5666666666666667)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.19285714285714284, subjectivity=0.7678571428571428)
# Sentiment(polarity=-0.15, subjectivity=0.4)
# Sentiment(polarity=0.9765625, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Sentiment(polarity=-0.5, subjectivity=0.7)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05000000000000001, subjectivity=0.4749999999999999)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.65, subjectivity=0.875)
# Sentiment(polarity=-0.30190972222222223, subjectivity=0.24444444444444446)
# Sentiment(polarity=-0.20416666666666666, subjectivity=0.65)
# Sentiment(polarity=-0.3816287878787879, subjectivity=0.6848484848484849)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1849537037037037, subjectivity=0.38842592592592595)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.09765625, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-1.0, subjectivity=0.9)
# Sentiment(polarity=0.04814814814814814, subjectivity=0.4962962962962963)
# Sentiment(polarity=-0.1, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.19444444444444448, subjectivity=0.2888888888888889)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.6000000000000001, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.24318181818181817, subjectivity=0.5522727272727272)
# Sentiment(polarity=-0.25, subjectivity=0.19999999999999996)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1625, subjectivity=0.4)
# Sentiment(polarity=-0.3499999999999999, subjectivity=0.5333333333333333)
# Sentiment(polarity=-0.17651515151515149, subjectivity=0.7070707070707071)
# Sentiment(polarity=-0.3125, subjectivity=0.8)
# Sentiment(polarity=-0.6, subjectivity=0.7)
# Sentiment(polarity=0.25, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.2, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3, subjectivity=0.4)
# Sentiment(polarity=-0.1482638888888889, subjectivity=0.4138888888888889)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0625)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.059999999999999984, subjectivity=0.7)
# Sentiment(polarity=-0.07692307692307693, subjectivity=0.2692307692307692)
# Sentiment(polarity=-0.625, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.625, subjectivity=0.29999999999999993)
# Sentiment(polarity=-1.0, subjectivity=0.52)
# Sentiment(polarity=-0.25, subjectivity=0.55)
# Sentiment(polarity=-0.05, subjectivity=0.25)
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# Sentiment(polarity=-0.22857142857142856, subjectivity=0.5089285714285714)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.4583333333333333, subjectivity=0.5333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15, subjectivity=0.65)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.2, subjectivity=0.7)
# Sentiment(polarity=-0.25, subjectivity=0.25)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=-0.075, subjectivity=0.15)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=-0.6, subjectivity=0.4)
# Sentiment(polarity=0.3, subjectivity=0.44166666666666665)
# Sentiment(polarity=-0.18125, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.6, subjectivity=1.0)
# Sentiment(polarity=-0.375, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.05)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.21212121212121213, subjectivity=0.48484848484848486)
# Sentiment(polarity=0.125, subjectivity=0.7534722222222222)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3, subjectivity=0.6)
# Sentiment(polarity=-0.19166666666666668, subjectivity=0.75)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.4)
# Sentiment(polarity=0.05, subjectivity=0.35)
# Sentiment(polarity=0.375, subjectivity=0.0)
# Sentiment(polarity=-0.9374999999999999, subjectivity=0.8333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.75, subjectivity=0.75)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=-0.525, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.19999999999999998, subjectivity=0.425)
# Sentiment(polarity=0.0, subjectivity=0.8)
# Sentiment(polarity=0.04166666666666666, subjectivity=0.625)
# Sentiment(polarity=-0.5, subjectivity=0.5)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=-0.4, subjectivity=0.4)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.5)
# Sentiment(polarity=-0.7999999999999999, subjectivity=1.0)
# Sentiment(polarity=-0.2986111111111111, subjectivity=0.33888888888888885)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.35, subjectivity=0.3)
# Sentiment(polarity=-0.25, subjectivity=0.15)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2333333333333333, subjectivity=0.5750000000000001)
# Sentiment(polarity=0.25, subjectivity=0.5)
# Sentiment(polarity=0.2, subjectivity=0.55)
# Sentiment(polarity=0.2222222222222222, subjectivity=0.6444444444444445)
# Sentiment(polarity=0.4, subjectivity=0.35)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=-0.125, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=-0.39999999999999997, subjectivity=0.5333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.175, subjectivity=0.4)
# Sentiment(polarity=-0.13333333333333333, subjectivity=0.5)
# Sentiment(polarity=-0.3, subjectivity=0.65)
# Sentiment(polarity=-0.75, subjectivity=1.0)
# Sentiment(polarity=-0.19090909090909092, subjectivity=0.35)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.875)
# Sentiment(polarity=-0.2878787878787879, subjectivity=0.6515151515151515)
# Sentiment(polarity=-0.30000000000000004, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.0045454545454545565, subjectivity=0.4348484848484849)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.1, subjectivity=0.35)
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.28409090909090906, subjectivity=0.48863636363636365)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.05, subjectivity=0.7)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=-0.2, subjectivity=0.05)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=-0.3, subjectivity=0.8)
# Sentiment(polarity=0.33333333333333337, subjectivity=0.8333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.2722222222222222, subjectivity=0.44444444444444453)
# Sentiment(polarity=-0.2333333333333333, subjectivity=0.4833333333333332)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.20833333333333331, subjectivity=0.3333333333333333)
# Sentiment(polarity=-0.4708333333333334, subjectivity=0.6291666666666667)
# Sentiment(polarity=0.35, subjectivity=0.32500000000000007)
# Sentiment(polarity=0.04375, subjectivity=0.3101190476190476)
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Sentiment(polarity=-0.35, subjectivity=0.5)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=-0.6, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.025, subjectivity=0.35833333333333334)
# Sentiment(polarity=0.16666666666666666, subjectivity=0.6666666666666666)
# Sentiment(polarity=-0.4, subjectivity=0.8)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.4083333333333334)
# Sentiment(polarity=-0.7, subjectivity=0.8250000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.8, subjectivity=0.9)
# Sentiment(polarity=-0.15, subjectivity=0.35)
# Sentiment(polarity=0.25, subjectivity=0.65)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3, subjectivity=0.44166666666666665)
# Sentiment(polarity=0.03749999999999999, subjectivity=0.58125)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.033333333333333326, subjectivity=0.6749999999999999)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.06666666666666667)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.3, subjectivity=0.7875)
# Sentiment(polarity=0.625, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.4166666666666667, subjectivity=0.5833333333333334)
# Sentiment(polarity=-0.05714285714285716, subjectivity=0.7678571428571428)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.4083333333333334)
# Sentiment(polarity=-0.03787878787878788, subjectivity=0.7811447811447811)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# Sentiment(polarity=0.012499999999999992, subjectivity=0.5666666666666668)
# Sentiment(polarity=1.0, subjectivity=0.75)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=-0.7999999999999999, subjectivity=1.0)
# Sentiment(polarity=0.13257575757575757, subjectivity=0.3696969696969697)
# Sentiment(polarity=0.11111111111111112, subjectivity=0.7000000000000001)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=-0.2, subjectivity=0.8)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.25, subjectivity=0.5)
# Sentiment(polarity=0.21212121212121213, subjectivity=0.48484848484848486)
# Sentiment(polarity=0.07878787878787881, subjectivity=0.4681818181818182)
# Sentiment(polarity=0.175, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Sentiment(polarity=-0.2333333333333333, subjectivity=0.7333333333333334)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=-0.009848484848484856, subjectivity=0.5515151515151515)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.4083333333333334)
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.2833333333333333)
# Sentiment(polarity=-0.3, subjectivity=0.8125)
# Sentiment(polarity=-0.26666666666666666, subjectivity=0.7333333333333334)
# Sentiment(polarity=-0.5, subjectivity=0.2)
# Sentiment(polarity=0.30000000000000004, subjectivity=0.55)
# Sentiment(polarity=-0.8, subjectivity=0.9)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.125, subjectivity=0.3)
# Sentiment(polarity=0.325, subjectivity=0.325)
# Sentiment(polarity=-0.3125, subjectivity=0.5249999999999999)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.20833333333333331)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.58, subjectivity=0.86)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=-0.15625, subjectivity=0.375)
# Sentiment(polarity=-0.4, subjectivity=0.8)
# Sentiment(polarity=-0.378125, subjectivity=0.45)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=-0.05454545454545454, subjectivity=0.3181818181818182)
# Sentiment(polarity=-0.475, subjectivity=0.9)
# Sentiment(polarity=-0.8, subjectivity=0.9)
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.20555555555555557, subjectivity=0.35555555555555557)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=-0.45, subjectivity=1.0)
# Sentiment(polarity=0.5208333333333334, subjectivity=0.5833333333333334)
# Sentiment(polarity=0.25, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.1, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.016666666666666663, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.26190476190476186, subjectivity=0.5119047619047619)
# Sentiment(polarity=0.0, subjectivity=0.6)
# Sentiment(polarity=0.024999999999999994, subjectivity=0.55)
# Sentiment(polarity=0.0, subjectivity=0.35714285714285715)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.35)
# Sentiment(polarity=0.7, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.4)
# Sentiment(polarity=-0.2333333333333333, subjectivity=0.5)
# Sentiment(polarity=0.14999999999999997, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.625, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.0625, subjectivity=0.35416666666666663)
# Sentiment(polarity=-0.75, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.5, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=0.1, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.375)
# Sentiment(polarity=0.5, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=1.0, subjectivity=0.4)
# Sentiment(polarity=0.6, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2215909090909091, subjectivity=0.34696969696969693)
# Sentiment(polarity=0.4055194805194805, subjectivity=0.6839285714285714)
# Sentiment(polarity=0.5, subjectivity=0.8000000000000002)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.35, subjectivity=0.35)
# Sentiment(polarity=0.8, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.17045454545454544, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.4, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.6000000000000001, subjectivity=0.625)
# Sentiment(polarity=0.375, subjectivity=0.47500000000000003)
# Sentiment(polarity=0.31666666666666665, subjectivity=0.5777777777777777)
# Sentiment(polarity=0.15333333333333332, subjectivity=0.7799999999999999)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.6944444444444444)
# Sentiment(polarity=0.8, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# Sentiment(polarity=0.2, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.0625, subjectivity=0.2375)
# Sentiment(polarity=0.7500000000000001, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=-0.2, subjectivity=0.4)
# Sentiment(polarity=0.25357142857142856, subjectivity=0.525)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.19999999999999998, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.07986111111111112, subjectivity=0.45555555555555555)
# Sentiment(polarity=0.4787878787878787, subjectivity=0.6848484848484849)
# Sentiment(polarity=0.06666666666666667, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.4)
# Sentiment(polarity=0.2681818181818182, subjectivity=0.6272727272727273)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.48828125, subjectivity=0.25)
# Sentiment(polarity=0.05, subjectivity=0.35)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.525, subjectivity=0.85)
# Sentiment(polarity=0.2556818181818182, subjectivity=0.7272727272727273)
# Sentiment(polarity=0.2, subjectivity=0.3833333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.3)
# Sentiment(polarity=0.25, subjectivity=1.0)
# Sentiment(polarity=0.2, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.09242424242424242, subjectivity=0.20530303030303032)
# Sentiment(polarity=0.21428571428571427, subjectivity=0.5714285714285714)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.5666666666666668)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.25, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.8333333333333334)
# Sentiment(polarity=-0.07777777777777779, subjectivity=0.14444444444444446)
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.011338383838383847, subjectivity=0.31868686868686863)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.21746031746031744, subjectivity=0.35634920634920636)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Sentiment(polarity=0.2681818181818182, subjectivity=0.6272727272727273)
# Sentiment(polarity=0.41666666666666663, subjectivity=0.8333333333333334)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.22121212121212122, subjectivity=0.48484848484848486)
# Sentiment(polarity=0.0, subjectivity=0.15000000000000002)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.425, subjectivity=0.7625)
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# Sentiment(polarity=0.05, subjectivity=0.15)
# Sentiment(polarity=0.5, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.0212121212121212, subjectivity=0.6181818181818182)
# Sentiment(polarity=0.5, subjectivity=0.55)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4681818181818182, subjectivity=0.6022727272727273)
# Sentiment(polarity=0.8, subjectivity=0.7)
# Sentiment(polarity=0.4, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.7, subjectivity=0.8)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=1.0)
# Sentiment(polarity=0.4340909090909091, subjectivity=0.475)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.11458333333333329, subjectivity=0.4083333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.45, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.6, subjectivity=0.95)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.7083333333333334)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15, subjectivity=0.4)
# Sentiment(polarity=-0.9750000000000001, subjectivity=0.9750000000000001)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=1.0, subjectivity=0.4)
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.6583333333333333)
# Sentiment(polarity=0.21212121212121213, subjectivity=0.3181818181818182)
# Sentiment(polarity=0.225, subjectivity=0.2)
# Sentiment(polarity=0.375, subjectivity=0.41666666666666663)
# Sentiment(polarity=0.24666666666666667, subjectivity=0.42666666666666664)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4121212121212121, subjectivity=0.8333333333333334)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.23583333333333334, subjectivity=0.56)
# Sentiment(polarity=-0.4, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.5, subjectivity=0.15)
# Sentiment(polarity=-0.13181818181818183, subjectivity=0.45)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.8333333333333334)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2681818181818182, subjectivity=0.42727272727272725)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.75, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.55, subjectivity=0.75)
# Sentiment(polarity=0.2537878787878788, subjectivity=0.6181818181818182)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.26666666666666666, subjectivity=0.2833333333333333)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Sentiment(polarity=-0.24583333333333335, subjectivity=0.4708333333333333)
# Sentiment(polarity=0.25, subjectivity=1.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.375, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.45, subjectivity=0.8)
# Sentiment(polarity=-0.5, subjectivity=0.9)
# Sentiment(polarity=0.125, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.025000000000000022, subjectivity=0.525)
# Sentiment(polarity=-0.20833333333333334, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.8, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.225, subjectivity=0.73125)
# Sentiment(polarity=0.1, subjectivity=0.9)
# Sentiment(polarity=0.1, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.2)
# Sentiment(polarity=0.8, subjectivity=0.7)
# Sentiment(polarity=0.25, subjectivity=0.3)
# Sentiment(polarity=0.09545454545454546, subjectivity=0.23484848484848486)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.6, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0909090909090909, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.46875, subjectivity=0.9)
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.3)
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.11249999999999999, subjectivity=0.575)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.14545454545454545, subjectivity=0.5681818181818182)
# Sentiment(polarity=0.0, subjectivity=0.125)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.375, subjectivity=0.41666666666666663)
# Sentiment(polarity=-0.3125, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.584090909090909, subjectivity=0.48863636363636365)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=0.29999999999999993)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.20000000000000004, subjectivity=0.5333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.24285714285714285, subjectivity=0.3678571428571429)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.125, subjectivity=0.125)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.06666666666666667, subjectivity=0.03333333333333333)
# Sentiment(polarity=0.2333333333333333, subjectivity=0.5333333333333333)
# Sentiment(polarity=0.4, subjectivity=0.6)
# Sentiment(polarity=1.0, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.175, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2109375, subjectivity=0.59375)
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.125, subjectivity=0.5)
# Sentiment(polarity=0.525, subjectivity=0.85)
# Sentiment(polarity=-0.4, subjectivity=0.7)
# Sentiment(polarity=0.03333333333333333, subjectivity=0.3)
# Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# Sentiment(polarity=0.65, subjectivity=0.625)
# Sentiment(polarity=-0.4318181818181818, subjectivity=0.5606060606060606)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.125, subjectivity=0.5)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.225, subjectivity=0.49142857142857144)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.02121212121212122, subjectivity=0.4181818181818182)
# Sentiment(polarity=0.2, subjectivity=0.5714285714285714)
# Sentiment(polarity=0.1, subjectivity=0.0)
# Sentiment(polarity=0.15, subjectivity=0.75)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.19999999999999998, subjectivity=0.6499999999999999)
# Sentiment(polarity=0.0625, subjectivity=0.4125)
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.9, subjectivity=0.75)
# Sentiment(polarity=0.65, subjectivity=0.6999999999999998)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.9)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.25)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.75)
# Sentiment(polarity=0.4, subjectivity=0.4)
# Sentiment(polarity=0.45, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.375, subjectivity=0.2)
# Sentiment(polarity=0.125, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.178125, subjectivity=0.65)
# Sentiment(polarity=0.3, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=-0.6, subjectivity=0.9)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.07777777777777779, subjectivity=0.45)
# Sentiment(polarity=-0.07500000000000001, subjectivity=0.85)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# ...
# Sentiment(polarity=0.9, subjectivity=1.0)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=-0.25, subjectivity=0.375)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4000000000000001, subjectivity=0.7666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.05, subjectivity=0.4)
# Sentiment(polarity=-0.22499999999999992, subjectivity=0.8333333333333333)
# Sentiment(polarity=0.1, subjectivity=0.1)
# Sentiment(polarity=0.625, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3121212121212121, subjectivity=0.5348484848484848)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.59375, subjectivity=0.6)
# Sentiment(polarity=0.375, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.32916666666666666, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.18333333333333335, subjectivity=0.37500000000000006)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.5125, subjectivity=0.5583333333333333)
# Sentiment(polarity=0.2, subjectivity=0.5)
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.4000000000000001)
# Sentiment(polarity=0.35, subjectivity=0.65)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.125, subjectivity=0.31666666666666665)
# Sentiment(polarity=0.40625, subjectivity=0.6)
# Sentiment(polarity=0.5333333333333334, subjectivity=0.5375)
# Sentiment(polarity=0.5, subjectivity=0.6)
# Sentiment(polarity=0.625, subjectivity=0.6)
# Sentiment(polarity=0.06666666666666667, subjectivity=0.03333333333333333)
# Sentiment(polarity=0.1, subjectivity=1.0)
# Sentiment(polarity=0.5681818181818181, subjectivity=0.37727272727272726)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.625, subjectivity=0.7999999999999999)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3852272727272727, subjectivity=0.7022727272727273)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.35714285714285715, subjectivity=0.8214285714285714)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.20778769841269842, subjectivity=0.453968253968254)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.2)
# Sentiment(polarity=0.1, subjectivity=0.9)
# Sentiment(polarity=0.2, subjectivity=0.6)
# Sentiment(polarity=0.25, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.42500000000000004, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=0.3125, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.75)
# Sentiment(polarity=0.20833333333333334, subjectivity=0.358974358974359)
# Sentiment(polarity=0.55, subjectivity=0.375)
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.4681818181818182, subjectivity=0.6022727272727273)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3547619047619048, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.225, subjectivity=0.6)
# Sentiment(polarity=0.4375, subjectivity=0.65)
# Sentiment(polarity=0.7500000000000001, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4193181818181818, subjectivity=0.7238636363636364)
# Sentiment(polarity=0.4375, subjectivity=0.775)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.3, subjectivity=0.825)
# Sentiment(polarity=0.1, subjectivity=1.0)
# Sentiment(polarity=0.04999999999999999, subjectivity=0.55)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.17222222222222222, subjectivity=0.6444444444444445)
# Sentiment(polarity=0.5121212121212121, subjectivity=0.7848484848484848)
# Sentiment(polarity=0.78125, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.6)
# Sentiment(polarity=0.3125, subjectivity=0.5)
# Sentiment(polarity=0.25, subjectivity=0.5)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.45, subjectivity=0.65)
# Sentiment(polarity=0.09999999999999998, subjectivity=0.8)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.26633522727272724, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.17045454545454544, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.3, subjectivity=0.0)
# Sentiment(polarity=-0.20833333333333331, subjectivity=0.3333333333333333)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=0.275, subjectivity=0.9)
# Sentiment(polarity=0.5, subjectivity=0.8)
# Sentiment(polarity=-0.05, subjectivity=0.2625)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3547619047619048, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.4875, subjectivity=0.575)
# Sentiment(polarity=-0.06287878787878788, subjectivity=0.3140151515151515)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.4)
# Sentiment(polarity=0.5, subjectivity=0.4833333333333333)
# Sentiment(polarity=-0.125, subjectivity=0.4)
# Sentiment(polarity=0.96875, subjectivity=0.975)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5681818181818181, subjectivity=0.37727272727272726)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.020000000000000018, subjectivity=0.8800000000000001)
# Sentiment(polarity=0.7, subjectivity=0.9)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.44000000000000006, subjectivity=0.66)
# Sentiment(polarity=0.40909090909090906, subjectivity=0.5136363636363637)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.48750000000000004, subjectivity=0.45)
# Sentiment(polarity=0.5852272727272727, subjectivity=0.7272727272727273)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.1, subjectivity=0.2)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.3416666666666666, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3040909090909091, subjectivity=0.6386363636363637)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.475, subjectivity=0.6)
# Sentiment(polarity=0.125, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.55, subjectivity=1.0)
# Sentiment(polarity=0.4375, subjectivity=0.6472222222222223)
# Sentiment(polarity=0.30000000000000004, subjectivity=0.5)
# Sentiment(polarity=0.07499999999999998, subjectivity=0.525)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=1.0, subjectivity=0.85)
# Sentiment(polarity=0.36818181818181817, subjectivity=0.7022727272727273)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.06818181818181818, subjectivity=0.2606060606060606)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3, subjectivity=0.975)
# Sentiment(polarity=0.3, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.475)
# Sentiment(polarity=0.75, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.375, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.5852272727272727, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.23333333333333334, subjectivity=0.55)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.2722222222222222, subjectivity=0.44444444444444453)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.36818181818181817, subjectivity=0.7022727272727273)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.8125, subjectivity=1.0)
# Sentiment(polarity=0.3547619047619048, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.286525974025974, subjectivity=0.5467532467532467)
# Sentiment(polarity=0.26666666666666666, subjectivity=0.2333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.10714285714285715, subjectivity=0.3678571428571429)
# Sentiment(polarity=0.13333333333333333, subjectivity=0.2333333333333333)
# Sentiment(polarity=0.5681818181818181, subjectivity=0.7272727272727273)
# Sentiment(polarity=0.375, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.26250000000000007, subjectivity=0.5041666666666667)
# Sentiment(polarity=0.8125, subjectivity=0.75)
# Sentiment(polarity=0.3, subjectivity=0.0)
# Sentiment(polarity=0.26666666666666666, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.15340909090909088, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.4, subjectivity=0.6)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=1.0, subjectivity=0.3)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.125, subjectivity=0.1)
# Sentiment(polarity=0.19999999999999998, subjectivity=0.5833333333333334)
# Sentiment(polarity=0.6, subjectivity=0.9)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1625, subjectivity=0.25)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=-0.25, subjectivity=0.375)
# Sentiment(polarity=0.5, subjectivity=0.475)
# Sentiment(polarity=0.6, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.525, subjectivity=0.625)
# Sentiment(polarity=0.13666666666666666, subjectivity=0.9266666666666667)
# Sentiment(polarity=0.1515151515151515, subjectivity=0.3939393939393939)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.12784090909090912, subjectivity=0.5636363636363637)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.125, subjectivity=0.55)
# Sentiment(polarity=0.23409090909090907, subjectivity=0.6886363636363636)
# Sentiment(polarity=0.2556818181818182, subjectivity=0.6022727272727273)
# Sentiment(polarity=-0.23333333333333334, subjectivity=0.5333333333333333)
# Sentiment(polarity=0.1875, subjectivity=0.45)
# Sentiment(polarity=0.65, subjectivity=0.7)
# Sentiment(polarity=0.18, subjectivity=0.31999999999999995)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3181818181818182, subjectivity=0.5772727272727273)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=-0.2916666666666667, subjectivity=0.5416666666666666)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.31875, subjectivity=0.46249999999999997)
# Sentiment(polarity=-0.375, subjectivity=0.3)
# Sentiment(polarity=0.35, subjectivity=0.65)
# Sentiment(polarity=0.34545454545454546, subjectivity=0.6)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.8, subjectivity=0.75)
# Sentiment(polarity=0.25, subjectivity=1.0)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.15340909090909088, subjectivity=0.4772727272727273)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.175, subjectivity=0.325)
# Sentiment(polarity=0.20778769841269842, subjectivity=0.453968253968254)
# Sentiment(polarity=0.5556818181818182, subjectivity=0.7272727272727273)
# Sentiment(polarity=0.5, subjectivity=0.6)
# Sentiment(polarity=0.4121212121212121, subjectivity=0.8015151515151514)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.4375, subjectivity=0.625)
# Sentiment(polarity=0.25, subjectivity=0.25)
# Sentiment(polarity=0.41, subjectivity=0.5666666666666667)
# Sentiment(polarity=0.14507575757575755, subjectivity=0.5257575757575758)
# Sentiment(polarity=0.36666666666666664, subjectivity=0.3666666666666667)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.25, subjectivity=0.2)
# Sentiment(polarity=0.36727272727272725, subjectivity=0.5909090909090909)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.2833333333333334, subjectivity=0.9666666666666667)
# Sentiment(polarity=0.1, subjectivity=1.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.2602272727272727, subjectivity=0.525)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.35, subjectivity=0.35)
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Sentiment(polarity=0.4374999999999999, subjectivity=0.6666666666666666)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2601298701298701, subjectivity=0.7694805194805194)
# Sentiment(polarity=0.6, subjectivity=1.0)
# Sentiment(polarity=0.5, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2556818181818182, subjectivity=0.4772727272727273)
# Sentiment(polarity=0.625, subjectivity=0.6)
# Sentiment(polarity=0.25, subjectivity=0.2)
# Sentiment(polarity=0.5, subjectivity=0.8)
# Sentiment(polarity=0.5, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.22500000000000006, subjectivity=0.65)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.25, subjectivity=0.44999999999999996)
# Sentiment(polarity=0.25, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.875, subjectivity=0.6000000000000001)
# Sentiment(polarity=-0.007142857142857173, subjectivity=0.7285714285714286)
# Sentiment(polarity=0.5, subjectivity=0.55)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.8)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.39999999999999997, subjectivity=0.8)
# Sentiment(polarity=-0.26250000000000007, subjectivity=0.5041666666666667)
# Sentiment(polarity=0.27878787878787875, subjectivity=0.5515151515151515)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.6, subjectivity=1.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=-0.8928571428571429, subjectivity=0.8571428571428571)
# Sentiment(polarity=0.3, subjectivity=0.1)
# Sentiment(polarity=0.5, subjectivity=0.6)
# Sentiment(polarity=0.2833333333333333, subjectivity=0.611111111111111)
# Sentiment(polarity=0.15625, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.15625, subjectivity=0.75)
# Sentiment(polarity=0.30000000000000004, subjectivity=0.75)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.3125, subjectivity=0.2)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.5)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.25, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
from textblob.sentiments import NaiveBayesAnalyzer

for tweet in corpus_tweet: 
    print(TextBlob(tweet, analyzer = NaiveBayesAnalyzer()).sentiment)
# Out:
# Sentiment(classification='neg', p_pos=0.2948207316862489, p_neg=0.705179268313751)
# Sentiment(classification='pos', p_pos=0.6384008120125728, p_neg=0.36159918798742713)
# Sentiment(classification='neg', p_pos=0.07049096981680504, p_neg=0.9295090301831933)
# Sentiment(classification='pos', p_pos=0.9884538689663167, p_neg=0.011546131033682525)
# Sentiment(classification='pos', p_pos=0.7317386645305264, p_neg=0.26826133546947545)
# Sentiment(classification='neg', p_pos=0.38667895472133784, p_neg=0.6133210452786618)
# Sentiment(classification='pos', p_pos=0.5634606694158041, p_neg=0.4365393305841984)
# Sentiment(classification='pos', p_pos=0.6780874296921514, p_neg=0.32191257030784964)
# Sentiment(classification='pos', p_pos=0.7636065063460601, p_neg=0.2363934936539405)
# Sentiment(classification='neg', p_pos=0.08012786565584745, p_neg=0.91987213434415)
# Sentiment(classification='pos', p_pos=0.884857542135599, p_neg=0.11514245786440053)
# Sentiment(classification='pos', p_pos=0.8174341985816824, p_neg=0.18256580141831724)
# Sentiment(classification='pos', p_pos=0.672011661807581, p_neg=0.3279883381924202)
# Sentiment(classification='neg', p_pos=0.1723672392985013, p_neg=0.8276327607014985)
# Sentiment(classification='neg', p_pos=0.14928396467536828, p_neg=0.8507160353246311)
# Sentiment(classification='pos', p_pos=0.5862550404094161, p_neg=0.4137449595905831)
# Sentiment(classification='pos', p_pos=0.8766222656319033, p_neg=0.12337773436809527)
# Sentiment(classification='neg', p_pos=0.30968865064313705, p_neg=0.6903113493568611)
# Sentiment(classification='pos', p_pos=0.8875473766797196, p_neg=0.11245262332028136)
# Sentiment(classification='neg', p_pos=0.1960703064293012, p_neg=0.8039296935706997)
# Sentiment(classification='neg', p_pos=0.2905556196831211, p_neg=0.709444380316877)
# Sentiment(classification='pos', p_pos=0.9237691826585386, p_neg=0.07623081734146037)
# Sentiment(classification='pos', p_pos=0.6537407937107967, p_neg=0.34625920628920265)
# Sentiment(classification='pos', p_pos=0.9676317506278159, p_neg=0.032368249372182)
# Sentiment(classification='neg', p_pos=0.1257788108193628, p_neg=0.8742211891806378)
# Sentiment(classification='pos', p_pos=0.5612813370473538, p_neg=0.43871866295264644)
# Sentiment(classification='pos', p_pos=0.6660093328613315, p_neg=0.3339906671386697)
# Sentiment(classification='neg', p_pos=0.4813097349560364, p_neg=0.5186902650439635)
# Sentiment(classification='pos', p_pos=0.9073295396739989, p_neg=0.09267046032600176)
# Sentiment(classification='pos', p_pos=0.9672399383984072, p_neg=0.03276006160158978)
# Sentiment(classification='pos', p_pos=0.8358521014934615, p_neg=0.16414789850654052)
# Sentiment(classification='pos', p_pos=0.6341548659025146, p_neg=0.3658451340974852)
# Sentiment(classification='pos', p_pos=0.7587881298107148, p_neg=0.24121187018928747)
# Sentiment(classification='pos', p_pos=0.5404294871292271, p_neg=0.4595705128707718)
# Sentiment(classification='neg', p_pos=0.34295795131454665, p_neg=0.6570420486854556)
# Sentiment(classification='pos', p_pos=0.5109534185783645, p_neg=0.48904658142163515)
# Sentiment(classification='pos', p_pos=0.9690871841882197, p_neg=0.03091281581177959)
# Sentiment(classification='pos', p_pos=0.5018243121877176, p_neg=0.49817568781228216)
# Sentiment(classification='pos', p_pos=0.5791816038623672, p_neg=0.42081839613763244)
# Sentiment(classification='neg', p_pos=0.449026507203697, p_neg=0.5509734927963017)
# Sentiment(classification='neg', p_pos=0.19598284270715546, p_neg=0.8040171572928434)
# Sentiment(classification='neg', p_pos=0.3529660352990449, p_neg=0.6470339647009562)
# Sentiment(classification='pos', p_pos=0.7236308770542053, p_neg=0.2763691229457925)
# Sentiment(classification='pos', p_pos=0.6997645723495234, p_neg=0.30023542765047717)
# Sentiment(classification='neg', p_pos=0.32817010170740313, p_neg=0.6718298982925948)
# Sentiment(classification='pos', p_pos=0.5840805554319138, p_neg=0.41591944456808383)
# Sentiment(classification='pos', p_pos=0.6030494296593993, p_neg=0.39695057034060105)
# Sentiment(classification='pos', p_pos=0.8713499999240326, p_neg=0.1286500000759653)
# Sentiment(classification='pos', p_pos=0.7114966557374853, p_neg=0.28850334426251434)
# Sentiment(classification='pos', p_pos=0.8989361702127653, p_neg=0.10106382978723413)
# Sentiment(classification='pos', p_pos=0.6875665039972778, p_neg=0.3124334960027213)
# Sentiment(classification='pos', p_pos=0.5276482599891792, p_neg=0.472351740010822)
# Sentiment(classification='neg', p_pos=0.2057986674285422, p_neg=0.7942013325714576)
# Sentiment(classification='neg', p_pos=0.17721900103865984, p_neg=0.8227809989613447)
# Sentiment(classification='neg', p_pos=0.30044355597200684, p_neg=0.6995564440279938)
# Sentiment(classification='pos', p_pos=0.7500215542760321, p_neg=0.24997844572396993)
# Sentiment(classification='neg', p_pos=0.03562586966611877, p_neg=0.9643741303338815)
# Sentiment(classification='pos', p_pos=0.7033391616898423, p_neg=0.29666083831015855)
# Sentiment(classification='pos', p_pos=0.9265990044917771, p_neg=0.0734009955082221)
# Sentiment(classification='neg', p_pos=0.14404159023194862, p_neg=0.8559584097680518)
# Sentiment(classification='pos', p_pos=0.5054838821218273, p_neg=0.49451611787817457)
# Sentiment(classification='pos', p_pos=0.8644932968487292, p_neg=0.13550670315127197)
# Sentiment(classification='neg', p_pos=0.025835527679366702, p_neg=0.9741644723206344)
# Sentiment(classification='neg', p_pos=0.3727730376285293, p_neg=0.6272269623714702)
# Sentiment(classification='pos', p_pos=0.9412125913056971, p_neg=0.058787408694303205)
# Sentiment(classification='pos', p_pos=0.5851063829787227, p_neg=0.41489361702127664)
# Sentiment(classification='neg', p_pos=0.2843340351830472, p_neg=0.7156659648169524)
# Sentiment(classification='neg', p_pos=0.15666347835221683, p_neg=0.8433365216477847)
# Sentiment(classification='pos', p_pos=0.8848846948975719, p_neg=0.11511530510242916)
# Sentiment(classification='neg', p_pos=0.4267555576406316, p_neg=0.573244442359368)
# Sentiment(classification='neg', p_pos=0.08316816890054317, p_neg=0.9168318310994523)
# Sentiment(classification='pos', p_pos=0.9690871841882197, p_neg=0.03091281581177959)
# Sentiment(classification='pos', p_pos=0.6906940125238801, p_neg=0.3093059874761188)
# Sentiment(classification='pos', p_pos=0.7334667188882971, p_neg=0.26653328111170155)
# Sentiment(classification='neg', p_pos=0.2787069661730069, p_neg=0.7212930338269936)
# Sentiment(classification='pos', p_pos=0.9808340246918353, p_neg=0.01916597530816219)
# Sentiment(classification='pos', p_pos=0.9102730169010707, p_neg=0.08972698309892885)
# Sentiment(classification='neg', p_pos=0.060640948955966, p_neg=0.9393590510440358)
# Sentiment(classification='neg', p_pos=0.4379598263384537, p_neg=0.5620401736615448)
# Sentiment(classification='pos', p_pos=0.7500215542760321, p_neg=0.24997844572396993)
# Sentiment(classification='pos', p_pos=0.6116537989275206, p_neg=0.3883462010724805)
# Sentiment(classification='pos', p_pos=0.6472155928497532, p_neg=0.3527844071502505)
# Sentiment(classification='pos', p_pos=0.6792099633314245, p_neg=0.32079003666857353)
# Sentiment(classification='pos', p_pos=0.7523655505725297, p_neg=0.24763444942747176)
# Sentiment(classification='pos', p_pos=0.6016454964932728, p_neg=0.3983545035067268)
# Sentiment(classification='neg', p_pos=0.1735568878973787, p_neg=0.8264431121026213)
# Sentiment(classification='pos', p_pos=0.930173387237757, p_neg=0.06982661276224034)
# Sentiment(classification='pos', p_pos=0.7793030221969286, p_neg=0.2206969778030702)
# Sentiment(classification='pos', p_pos=0.7178655479483576, p_neg=0.2821344520516434)
# Sentiment(classification='pos', p_pos=0.6902361987594147, p_neg=0.3097638012405858)
# Sentiment(classification='pos', p_pos=0.9984983320378362, p_neg=0.0015016679621644264)
# Sentiment(classification='pos', p_pos=0.9479479067429434, p_neg=0.05205209325705847)
# Sentiment(classification='neg', p_pos=0.17164392222481153, p_neg=0.8283560777751888)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-becb1e06f7e2> in <module>
#       2
#       3 for tweet in corpus_tweet:
# ----> 4     print(TextBlob(tweet, analyzer = NaiveBayesAnalyzer()).sentiment)
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/blob.py in sentiment(self)
#     430         :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     431         """
# --> 432         return self.analyzer.analyze(self.raw)
#     433
#     434     @cached_property
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/en/sentiments.py in analyze(self, text)
#      86         """
#      87         # Lazily train the classifier
# ---> 88         super(NaiveBayesAnalyzer, self).analyze(text)
#      89         tokens = word_tokenize(text, include_punc=False)
#      90         filtered = (t.lower() for t in tokens if len(t) >= 3)
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/base.py in analyze(self, text)
#      92         # Lazily train the classifier
#      93         if not self._trained:
# ---> 94             self.train()
#      95         # Analyze text
#      96         return None
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/decorators.py in decorated(*args, **kwargs)
#      33     def decorated(*args, **kwargs):
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/en/sentiments.py in train(self)
#      74         neg_ids = nltk.corpus.movie_reviews.fileids('neg')
#      75         pos_ids = nltk.corpus.movie_reviews.fileids('pos')
# ---> 76         neg_feats = [(self.feature_extractor(
#      77             nltk.corpus.movie_reviews.words(fileids=[f])), 'neg') for f in neg_ids]
#      78         pos_feats = [(self.feature_extractor(
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/en/sentiments.py in <listcomp>(.0)
#      74         neg_ids = nltk.corpus.movie_reviews.fileids('neg')
#      75         pos_ids = nltk.corpus.movie_reviews.fileids('pos')
# ---> 76         neg_feats = [(self.feature_extractor(
#      77             nltk.corpus.movie_reviews.words(fileids=[f])), 'neg') for f in neg_ids]
#      78         pos_feats = [(self.feature_extractor(
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/en/sentiments.py in _default_feature_extractor(words)
#      47 def _default_feature_extractor(words):
#      48     """Default feature extractor for the NaiveBayesAnalyzer."""
# ---> 49     return dict(((word, True) for word in words))
#      50
#      51
#
# ~/anaconda3/lib/python3.8/site-packages/textblob/en/sentiments.py in <genexpr>(.0)
#      47 def _default_feature_extractor(words):
#      48     """Default feature extractor for the NaiveBayesAnalyzer."""
# ---> 49     return dict(((word, True) for word in words))
#      50
#      51
#
# ~/anaconda3/lib/python3.8/site-packages/nltk/corpus/reader/util.py in iterate_from(self, start_tok)
#     294             self._current_toknum = toknum
#     295             self._current_blocknum = block_index
# --> 296             tokens = self.read_block(self._stream)
#     297             assert isinstance(tokens, (tuple, list, AbstractLazySequence)), (
#     298                 "block reader %s() should return list or tuple."
#
# ~/anaconda3/lib/python3.8/site-packages/nltk/corpus/reader/plaintext.py in _read_word_block(self, stream)
#     132         words = []
#     133         for i in range(20):  # Read 20 lines at a time.
# --> 134             words.extend(self._word_tokenizer.tokenize(stream.readline()))
#     135         return words
#     136
#
# ~/anaconda3/lib/python3.8/site-packages/nltk/tokenize/regexp.py in tokenize(self, text)
#     131         # If our regexp matches tokens, use re.findall:
#     132         else:
# --> 133             return self._regexp.findall(text)
#     134
#     135     def span_tokenize(self, text):
#
# KeyboardInterrupt:

# %% [markdown]
# ### 4.1.2. VADER ('Valence Aware Dictionary and sEntiment Reasoner’)
#
# VADER is a lexicon and rule-based sentiment analysis tool, used to analyze the sentiment of a text.
#
# Lexicon is a list of lexical features (words) that are labeled with positive or negative based on the semantic meaning [[8]](https://medium.com/analytics-vidhya/sentiment-analysis-with-vader-label-the-unlabeled-data-8dd785225166).
#
# Even an unlabelled text data can be labeled with VADER sentiment analyzer, as we'll see ahead:

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

vds = SentimentIntensityAnalyzer()

for tweet in corpus_tweet:
    print(vds.polarity_scores(tweet))
# Out:
# {'neg': 0.22, 'neu': 0.636, 'pos': 0.145, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.4404}
# {'neg': 0.376, 'neu': 0.523, 'pos': 0.101, 'compound': -0.8357}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.6114}
# {'neg': 0.212, 'neu': 0.788, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.237, 'neu': 0.763, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.234, 'neu': 0.766, 'pos': 0.0, 'compound': -0.5983}
# {'neg': 0.221, 'neu': 0.779, 'pos': 0.0, 'compound': -0.5229}
# {'neg': 0.486, 'neu': 0.342, 'pos': 0.171, 'compound': -0.6808}
# {'neg': 0.143, 'neu': 0.857, 'pos': 0.0, 'compound': -0.4614}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.049, 'neu': 0.585, 'pos': 0.366, 'compound': 0.8834}
# {'neg': 0.432, 'neu': 0.568, 'pos': 0.0, 'compound': -0.5859}
# {'neg': 0.521, 'neu': 0.479, 'pos': 0.0, 'compound': -0.6633}
# {'neg': 0.54, 'neu': 0.46, 'pos': 0.0, 'compound': -0.8906}
# {'neg': 0.342, 'neu': 0.658, 'pos': 0.0, 'compound': -0.5638}
# {'neg': 0.14, 'neu': 0.766, 'pos': 0.094, 'compound': -0.2695}
# {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.3612}
# {'neg': 0.28, 'neu': 0.381, 'pos': 0.339, 'compound': 0.4342}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.099, 'neu': 0.706, 'pos': 0.195, 'compound': 0.4678}
# {'neg': 0.214, 'neu': 0.451, 'pos': 0.336, 'compound': 0.3218}
# {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.4404}
# {'neg': 0.074, 'neu': 0.724, 'pos': 0.202, 'compound': 0.5508}
# {'neg': 0.778, 'neu': 0.222, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.7184}
# {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.5009}
# {'neg': 0.104, 'neu': 0.772, 'pos': 0.124, 'compound': 0.128}
# {'neg': 0.128, 'neu': 0.872, 'pos': 0.0, 'compound': -0.4215}
# {'neg': 0.166, 'neu': 0.63, 'pos': 0.204, 'compound': -0.089}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.09, 'neu': 0.776, 'pos': 0.134, 'compound': 0.2714}
# {'neg': 0.163, 'neu': 0.837, 'pos': 0.0, 'compound': -0.5983}
# {'neg': 0.188, 'neu': 0.692, 'pos': 0.12, 'compound': -0.3544}
# {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.3412}
# {'neg': 0.143, 'neu': 0.857, 'pos': 0.0, 'compound': -0.3612}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.276, 'neu': 0.724, 'pos': 0.0, 'compound': -0.6369}
# {'neg': 0.225, 'neu': 0.435, 'pos': 0.34, 'compound': -0.1491}
# {'neg': 0.219, 'neu': 0.675, 'pos': 0.105, 'compound': -0.4019}
# {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.118, 'neu': 0.775, 'pos': 0.107, 'compound': -0.0772}
# {'neg': 0.186, 'neu': 0.814, 'pos': 0.0, 'compound': -0.5983}
# {'neg': 0.235, 'neu': 0.494, 'pos': 0.272, 'compound': 0.296}
# {'neg': 0.209, 'neu': 0.791, 'pos': 0.0, 'compound': -0.6767}
# {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4003}
# {'neg': 0.383, 'neu': 0.617, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.29, 'neu': 0.71, 'pos': 0.0, 'compound': -0.5046}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.478, 'neu': 0.522, 'pos': 0.0, 'compound': -0.8091}
# {'neg': 0.343, 'neu': 0.571, 'pos': 0.086, 'compound': -0.802}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.208, 'neu': 0.612, 'pos': 0.18, 'compound': -0.1779}
# {'neg': 0.126, 'neu': 0.874, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.346, 'neu': 0.654, 'pos': 0.0, 'compound': -0.877}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.32, 'neu': 0.536, 'pos': 0.143, 'compound': -0.453}
# {'neg': 0.162, 'neu': 0.838, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.132, 'neu': 0.659, 'pos': 0.21, 'compound': 0.3182}
# {'neg': 0.316, 'neu': 0.684, 'pos': 0.0, 'compound': -0.8127}
# {'neg': 0.125, 'neu': 0.654, 'pos': 0.221, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.367, 'neu': 0.633, 'pos': 0.0, 'compound': -0.4404}
# {'neg': 0.267, 'neu': 0.689, 'pos': 0.044, 'compound': -0.8004}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.369, 'neu': 0.574, 'pos': 0.057, 'compound': -0.8652}
# {'neg': 0.214, 'neu': 0.73, 'pos': 0.056, 'compound': -0.5716}
# {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.3612}
# {'neg': 0.362, 'neu': 0.638, 'pos': 0.0, 'compound': -0.6249}
# {'neg': 0.185, 'neu': 0.616, 'pos': 0.199, 'compound': 0.0516}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.051, 'neu': 0.665, 'pos': 0.285, 'compound': 0.8126}
# {'neg': 0.141, 'neu': 0.859, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.743}
# {'neg': 0.192, 'neu': 0.642, 'pos': 0.166, 'compound': -0.1779}
# {'neg': 0.117, 'neu': 0.883, 'pos': 0.0, 'compound': -0.4168}
# {'neg': 0.0, 'neu': 0.9, 'pos': 0.1, 'compound': 0.4404}
# {'neg': 0.258, 'neu': 0.63, 'pos': 0.112, 'compound': -0.6857}
# {'neg': 0.234, 'neu': 0.766, 'pos': 0.0, 'compound': -0.6784}
# {'neg': 0.371, 'neu': 0.629, 'pos': 0.0, 'compound': -0.6486}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.207, 'neu': 0.657, 'pos': 0.136, 'compound': -0.3612}
# {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.319, 'neu': 0.681, 'pos': 0.0, 'compound': -0.8176}
# {'neg': 0.145, 'neu': 0.789, 'pos': 0.066, 'compound': -0.2924}
# {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.5994}
# {'neg': 0.202, 'neu': 0.798, 'pos': 0.0, 'compound': -0.5848}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.346, 'neu': 0.503, 'pos': 0.151, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.4449}
# {'neg': 0.075, 'neu': 0.785, 'pos': 0.14, 'compound': 0.4434}
# {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.4199}
# {'neg': 0.219, 'neu': 0.781, 'pos': 0.0, 'compound': -0.6808}
# {'neg': 0.101, 'neu': 0.899, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.181, 'neu': 0.819, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.144, 'neu': 0.743, 'pos': 0.114, 'compound': -0.1531}
# {'neg': 0.193, 'neu': 0.807, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.0, 'neu': 0.768, 'pos': 0.232, 'compound': 0.7027}
# {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'compound': -0.6966}
# {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.2023}
# {'neg': 0.085, 'neu': 0.915, 'pos': 0.0, 'compound': -0.2144}
# {'neg': 0.245, 'neu': 0.545, 'pos': 0.209, 'compound': -0.1027}
# {'neg': 0.187, 'neu': 0.813, 'pos': 0.0, 'compound': -0.5707}
# {'neg': 0.083, 'neu': 0.722, 'pos': 0.195, 'compound': 0.4753}
# {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.6494}
# {'neg': 0.08, 'neu': 0.77, 'pos': 0.15, 'compound': 0.4434}
# {'neg': 0.125, 'neu': 0.678, 'pos': 0.198, 'compound': 0.2116}
# {'neg': 0.292, 'neu': 0.559, 'pos': 0.149, 'compound': -0.5093}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.39, 'neu': 0.61, 'pos': 0.0, 'compound': -0.8733}
# {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'compound': -0.4404}
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.3612}
# {'neg': 0.139, 'neu': 0.741, 'pos': 0.12, 'compound': -0.1007}
# {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.2732}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.329, 'neu': 0.671, 'pos': 0.0, 'compound': -0.7089}
# {'neg': 0.309, 'neu': 0.691, 'pos': 0.0, 'compound': -0.7104}
# {'neg': 0.099, 'neu': 0.761, 'pos': 0.14, 'compound': 0.1796}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.338, 'neu': 0.662, 'pos': 0.0, 'compound': -0.6808}
# {'neg': 0.117, 'neu': 0.883, 'pos': 0.0, 'compound': -0.2481}
# {'neg': 0.203, 'neu': 0.797, 'pos': 0.0, 'compound': -0.6239}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.298, 'neu': 0.634, 'pos': 0.069, 'compound': -0.8519}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.6114}
# {'neg': 0.291, 'neu': 0.709, 'pos': 0.0, 'compound': -0.802}
# {'neg': 0.328, 'neu': 0.672, 'pos': 0.0, 'compound': -0.6597}
# {'neg': 0.148, 'neu': 0.852, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.261, 'neu': 0.739, 'pos': 0.0, 'compound': -0.6408}
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.225, 'neu': 0.58, 'pos': 0.196, 'compound': -0.1027}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.34, 'neu': 0.66, 'pos': 0.0, 'compound': -0.7346}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.366, 'neu': 0.634, 'pos': 0.0, 'compound': -0.6825}
# {'neg': 0.086, 'neu': 0.763, 'pos': 0.151, 'compound': 0.3117}
# {'neg': 0.241, 'neu': 0.431, 'pos': 0.328, 'compound': 0.25}
# {'neg': 0.236, 'neu': 0.764, 'pos': 0.0, 'compound': -0.4753}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.288, 'neu': 0.712, 'pos': 0.0, 'compound': -0.8271}
# {'neg': 0.197, 'neu': 0.532, 'pos': 0.271, 'compound': 0.3368}
# {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'compound': -0.5473}
# {'neg': 0.431, 'neu': 0.378, 'pos': 0.191, 'compound': -0.836}
# {'neg': 0.085, 'neu': 0.664, 'pos': 0.251, 'compound': 0.5027}
# {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.3595}
# {'neg': 0.176, 'neu': 0.566, 'pos': 0.258, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.767, 'pos': 0.233, 'compound': 0.7717}
# {'neg': 0.095, 'neu': 0.702, 'pos': 0.203, 'compound': 0.3352}
# {'neg': 0.312, 'neu': 0.688, 'pos': 0.0, 'compound': -0.8602}
# {'neg': 0.084, 'neu': 0.916, 'pos': 0.0, 'compound': -0.2755}
# {'neg': 0.144, 'neu': 0.506, 'pos': 0.35, 'compound': 0.6486}
# {'neg': 0.193, 'neu': 0.657, 'pos': 0.15, 'compound': -0.296}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'compound': -0.7003}
# {'neg': 0.09, 'neu': 0.91, 'pos': 0.0, 'compound': -0.3111}
# {'neg': 0.214, 'neu': 0.786, 'pos': 0.0, 'compound': -0.717}
# {'neg': 0.417, 'neu': 0.583, 'pos': 0.0, 'compound': -0.5538}
# {'neg': 0.152, 'neu': 0.848, 'pos': 0.0, 'compound': -0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.173, 'neu': 0.827, 'pos': 0.0, 'compound': -0.6808}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.238, 'neu': 0.645, 'pos': 0.117, 'compound': -0.4588}
# {'neg': 0.142, 'neu': 0.858, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.165, 'neu': 0.835, 'pos': 0.0, 'compound': -0.6739}
# {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.254, 'neu': 0.604, 'pos': 0.143, 'compound': -0.4633}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.8316}
# {'neg': 0.209, 'neu': 0.683, 'pos': 0.108, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.213, 'neu': 0.664, 'pos': 0.123, 'compound': -0.4404}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.6114}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.319, 'neu': 0.681, 'pos': 0.0, 'compound': -0.8172}
# {'neg': 0.217, 'neu': 0.522, 'pos': 0.261, 'compound': 0.128}
# {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.6597}
# {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.5294}
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.5983}
# {'neg': 0.177, 'neu': 0.823, 'pos': 0.0, 'compound': -0.6732}
# {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.3818}
# {'neg': 0.181, 'neu': 0.725, 'pos': 0.094, 'compound': -0.34}
# {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'compound': -0.6083}
# {'neg': 0.246, 'neu': 0.508, 'pos': 0.246, 'compound': 0.0}
# {'neg': 0.666, 'neu': 0.334, 'pos': 0.0, 'compound': -0.6114}
# {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 0.883, 'pos': 0.117, 'compound': 0.4201}
# {'neg': 0.152, 'neu': 0.848, 'pos': 0.0, 'compound': -0.4689}
# {'neg': 0.611, 'neu': 0.389, 'pos': 0.0, 'compound': -0.8862}
# {'neg': 0.227, 'neu': 0.773, 'pos': 0.0, 'compound': -0.6908}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.234, 'neu': 0.597, 'pos': 0.169, 'compound': -0.3181}
# {'neg': 0.299, 'neu': 0.59, 'pos': 0.111, 'compound': -0.6635}
# {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.6697}
# {'neg': 0.072, 'neu': 0.928, 'pos': 0.0, 'compound': -0.1027}
# {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.6696}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.7184}
# {'neg': 0.391, 'neu': 0.471, 'pos': 0.138, 'compound': -0.7906}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.288, 'neu': 0.712, 'pos': 0.0, 'compound': -0.501}
# {'neg': 0.134, 'neu': 0.866, 'pos': 0.0, 'compound': -0.4199}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.3875}
# {'neg': 0.189, 'neu': 0.58, 'pos': 0.231, 'compound': 0.1511}
# {'neg': 0.128, 'neu': 0.766, 'pos': 0.106, 'compound': -0.1531}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.211, 'neu': 0.645, 'pos': 0.144, 'compound': -0.3291}
# {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.8858}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.086, 'neu': 0.914, 'pos': 0.0, 'compound': -0.285}
# {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'compound': 0.4019}
# {'neg': 0.372, 'neu': 0.628, 'pos': 0.0, 'compound': -0.877}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.078, 'neu': 0.735, 'pos': 0.188, 'compound': 0.4019}
# {'neg': 0.102, 'neu': 0.772, 'pos': 0.126, 'compound': 0.2003}
# {'neg': 0.078, 'neu': 0.922, 'pos': 0.0, 'compound': -0.1326}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.116, 'neu': 0.695, 'pos': 0.189, 'compound': 0.3544}
# {'neg': 0.183, 'neu': 0.817, 'pos': 0.0, 'compound': -0.6908}
# {'neg': 0.304, 'neu': 0.696, 'pos': 0.0, 'compound': -0.813}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.481, 'neu': 0.519, 'pos': 0.0, 'compound': -0.8481}
# {'neg': 0.0, 'neu': 0.671, 'pos': 0.329, 'compound': 0.5994}
# {'neg': 0.596, 'neu': 0.404, 'pos': 0.0, 'compound': -0.871}
# {'neg': 0.212, 'neu': 0.788, 'pos': 0.0, 'compound': -0.6174}
# {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.4184}
# {'neg': 0.147, 'neu': 0.853, 'pos': 0.0, 'compound': -0.4753}
# {'neg': 0.37, 'neu': 0.63, 'pos': 0.0, 'compound': -0.6908}
# {'neg': 0.177, 'neu': 0.823, 'pos': 0.0, 'compound': -0.6229}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.654, 'pos': 0.346, 'compound': 0.8908}
# {'neg': 0.15, 'neu': 0.85, 'pos': 0.0, 'compound': -0.4898}
# {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.4926}
# {'neg': 0.397, 'neu': 0.603, 'pos': 0.0, 'compound': -0.9161}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.375, 'neu': 0.545, 'pos': 0.08, 'compound': -0.8505}
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.6371}
# {'neg': 0.194, 'neu': 0.806, 'pos': 0.0, 'compound': -0.6538}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.212, 'neu': 0.663, 'pos': 0.125, 'compound': -0.2406}
# {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.2732}
# {'neg': 0.41, 'neu': 0.59, 'pos': 0.0, 'compound': -0.7067}
# {'neg': 0.0, 'neu': 0.731, 'pos': 0.269, 'compound': 0.7902}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.343, 'neu': 0.657, 'pos': 0.0, 'compound': -0.8564}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.128}
# {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.304, 'neu': 0.696, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.7574}
# {'neg': 0.313, 'neu': 0.523, 'pos': 0.164, 'compound': -0.4559}
# {'neg': 0.268, 'neu': 0.732, 'pos': 0.0, 'compound': -0.6597}
# {'neg': 0.098, 'neu': 0.682, 'pos': 0.22, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.8807}
# {'neg': 0.162, 'neu': 0.455, 'pos': 0.384, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.198, 'neu': 0.802, 'pos': 0.0, 'compound': -0.6351}
# {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.214, 'neu': 0.676, 'pos': 0.11, 'compound': -0.4404}
# {'neg': 0.316, 'neu': 0.684, 'pos': 0.0, 'compound': -0.7506}
# {'neg': 0.157, 'neu': 0.746, 'pos': 0.097, 'compound': -0.4279}
# {'neg': 0.275, 'neu': 0.588, 'pos': 0.137, 'compound': -0.34}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.4303}
# {'neg': 0.105, 'neu': 0.838, 'pos': 0.058, 'compound': -0.2263}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.237, 'neu': 0.763, 'pos': 0.0, 'compound': -0.7351}
# {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'compound': -0.5267}
# {'neg': 0.157, 'neu': 0.772, 'pos': 0.071, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.203, 'neu': 0.641, 'pos': 0.157, 'compound': -0.3182}
# {'neg': 0.368, 'neu': 0.632, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'compound': 0.1695}
# {'neg': 0.05, 'neu': 0.835, 'pos': 0.114, 'compound': 0.351}
# {'neg': 0.087, 'neu': 0.913, 'pos': 0.0, 'compound': -0.2263}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.536, 'neu': 0.464, 'pos': 0.0, 'compound': -0.9136}
# {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.323, 'neu': 0.677, 'pos': 0.0, 'compound': -0.7351}
# {'neg': 0.181, 'neu': 0.691, 'pos': 0.128, 'compound': -0.25}
# {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.3182}
# {'neg': 0.283, 'neu': 0.717, 'pos': 0.0, 'compound': -0.7269}
# {'neg': 0.11, 'neu': 0.772, 'pos': 0.118, 'compound': 0.0516}
# {'neg': 0.291, 'neu': 0.558, 'pos': 0.151, 'compound': -0.3624}
# {'neg': 0.292, 'neu': 0.438, 'pos': 0.27, 'compound': -0.3802}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.283, 'neu': 0.717, 'pos': 0.0, 'compound': -0.7717}
# {'neg': 0.248, 'neu': 0.632, 'pos': 0.119, 'compound': -0.3944}
# {'neg': 0.15, 'neu': 0.85, 'pos': 0.0, 'compound': -0.2755}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.12, 'neu': 0.813, 'pos': 0.067, 'compound': -0.3044}
# {'neg': 0.0, 'neu': 0.719, 'pos': 0.281, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.7391}
# {'neg': 0.345, 'neu': 0.655, 'pos': 0.0, 'compound': -0.8378}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.178, 'neu': 0.747, 'pos': 0.075, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.7506}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'compound': -0.3412}
# {'neg': 0.119, 'neu': 0.526, 'pos': 0.354, 'compound': 0.6908}
# {'neg': 0.232, 'neu': 0.663, 'pos': 0.105, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.42, 'neu': 0.58, 'pos': 0.0, 'compound': -0.8271}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.6369}
# {'neg': 0.388, 'neu': 0.612, 'pos': 0.0, 'compound': -0.8049}
# {'neg': 0.193, 'neu': 0.807, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.298, 'neu': 0.702, 'pos': 0.0, 'compound': -0.5267}
# {'neg': 0.238, 'neu': 0.762, 'pos': 0.0, 'compound': -0.5696}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.6369}
# {'neg': 0.32, 'neu': 0.68, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.084, 'neu': 0.916, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.25}
# {'neg': 0.069, 'neu': 0.649, 'pos': 0.281, 'compound': 0.7096}
# {'neg': 0.191, 'neu': 0.686, 'pos': 0.123, 'compound': -0.34}
# {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.4588}
# {'neg': 0.099, 'neu': 0.677, 'pos': 0.224, 'compound': 0.4133}
# {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.4215}
# {'neg': 0.219, 'neu': 0.781, 'pos': 0.0, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.4574}
# {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'compound': -0.5267}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.93, 'pos': 0.07, 'compound': 0.2235}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.3612}
# {'neg': 0.197, 'neu': 0.712, 'pos': 0.091, 'compound': -0.4003}
# {'neg': 0.098, 'neu': 0.836, 'pos': 0.065, 'compound': -0.2268}
# {'neg': 0.262, 'neu': 0.631, 'pos': 0.107, 'compound': -0.4939}
# {'neg': 0.201, 'neu': 0.799, 'pos': 0.0, 'compound': -0.7003}
# {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
# {'neg': 0.113, 'neu': 0.809, 'pos': 0.078, 'compound': -0.2221}
# {'neg': 0.181, 'neu': 0.819, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.177, 'neu': 0.748, 'pos': 0.075, 'compound': -0.4364}
# {'neg': 0.179, 'neu': 0.655, 'pos': 0.166, 'compound': -0.1027}
# {'neg': 0.099, 'neu': 0.901, 'pos': 0.0, 'compound': -0.0258}
# {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5267}
# {'neg': 0.152, 'neu': 0.696, 'pos': 0.152, 'compound': 0.0}
# {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.7003}
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.5994}
# {'neg': 0.106, 'neu': 0.792, 'pos': 0.102, 'compound': -0.0258}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.067, 'neu': 0.583, 'pos': 0.35, 'compound': 0.8809}
# {'neg': 0.147, 'neu': 0.705, 'pos': 0.147, 'compound': 0.0}
# {'neg': 0.261, 'neu': 0.739, 'pos': 0.0, 'compound': -0.7717}
# {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.1326}
# {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.138, 'neu': 0.691, 'pos': 0.171, 'compound': 0.4215}
# {'neg': 0.202, 'neu': 0.798, 'pos': 0.0, 'compound': -0.5859}
# {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.5228}
# {'neg': 0.167, 'neu': 0.737, 'pos': 0.097, 'compound': -0.4228}
# {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.3595}
# {'neg': 0.466, 'neu': 0.39, 'pos': 0.144, 'compound': -0.9348}
# {'neg': 0.098, 'neu': 0.784, 'pos': 0.118, 'compound': 0.1275}
# {'neg': 0.136, 'neu': 0.661, 'pos': 0.203, 'compound': 0.1548}
# {'neg': 0.17, 'neu': 0.83, 'pos': 0.0, 'compound': -0.4753}
# {'neg': 0.246, 'neu': 0.711, 'pos': 0.043, 'compound': -0.8338}
# {'neg': 0.308, 'neu': 0.603, 'pos': 0.089, 'compound': -0.7346}
# {'neg': 0.297, 'neu': 0.703, 'pos': 0.0, 'compound': -0.7469}
# {'neg': 0.237, 'neu': 0.763, 'pos': 0.0, 'compound': -0.4215}
# {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'compound': -0.25}
# {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.0772}
# {'neg': 0.123, 'neu': 0.702, 'pos': 0.175, 'compound': 0.2247}
# {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.5574}
# {'neg': 0.143, 'neu': 0.738, 'pos': 0.119, 'compound': -0.1531}
# {'neg': 0.48, 'neu': 0.424, 'pos': 0.096, 'compound': -0.9477}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.232, 'neu': 0.711, 'pos': 0.057, 'compound': -0.6883}
# {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compound': -0.5775}
# {'neg': 0.128, 'neu': 0.687, 'pos': 0.185, 'compound': 0.3034}
# {'neg': 0.134, 'neu': 0.866, 'pos': 0.0, 'compound': -0.5294}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'compound': 0.5267}
# {'neg': 0.227, 'neu': 0.623, 'pos': 0.15, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.227, 'neu': 0.672, 'pos': 0.101, 'compound': -0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'compound': -0.3412}
# {'neg': 0.538, 'neu': 0.462, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.15, 'neu': 0.725, 'pos': 0.126, 'compound': -0.128}
# {'neg': 0.325, 'neu': 0.675, 'pos': 0.0, 'compound': -0.5823}
# {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.4926}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.15, 'neu': 0.85, 'pos': 0.0, 'compound': -0.4585}
# {'neg': 0.242, 'neu': 0.662, 'pos': 0.096, 'compound': -0.6588}
# {'neg': 0.183, 'neu': 0.817, 'pos': 0.0, 'compound': -0.6305}
# {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3595}
# {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.7405}
# {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.6517}
# {'neg': 0.371, 'neu': 0.629, 'pos': 0.0, 'compound': -0.6289}
# {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.4574}
# {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'compound': 0.6369}
# {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.6174}
# {'neg': 0.545, 'neu': 0.455, 'pos': 0.0, 'compound': -0.5574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.153, 'neu': 0.641, 'pos': 0.206, 'compound': 0.1429}
# {'neg': 0.206, 'neu': 0.794, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.4939}
# {'neg': 0.262, 'neu': 0.603, 'pos': 0.136, 'compound': -0.3624}
# {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'compound': 0.4753}
# {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.6124}
# {'neg': 0.181, 'neu': 0.724, 'pos': 0.094, 'compound': -0.5805}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.102, 'neu': 0.795, 'pos': 0.102, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.163, 'neu': 0.837, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.227, 'neu': 0.683, 'pos': 0.09, 'compound': -0.6588}
# {'neg': 0.079, 'neu': 0.614, 'pos': 0.307, 'compound': 0.7424}
# {'neg': 0.293, 'neu': 0.537, 'pos': 0.169, 'compound': -0.4588}
# {'neg': 0.346, 'neu': 0.654, 'pos': 0.0, 'compound': -0.6486}
# {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.655, 'pos': 0.345, 'compound': 0.749}
# {'neg': 0.787, 'neu': 0.213, 'pos': 0.0, 'compound': -0.5719}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.133, 'neu': 0.867, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.0, 'neu': 0.938, 'pos': 0.062, 'compound': 0.1007}
# {'neg': 0.132, 'neu': 0.868, 'pos': 0.0, 'compound': -0.3802}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.196, 'neu': 0.64, 'pos': 0.164, 'compound': -0.2023}
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.6371}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.236, 'neu': 0.764, 'pos': 0.0, 'compound': -0.4738}
# {'neg': 0.239, 'neu': 0.761, 'pos': 0.0, 'compound': -0.6597}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.092, 'neu': 0.71, 'pos': 0.198, 'compound': 0.3595}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.375, 'neu': 0.542, 'pos': 0.083, 'compound': -0.8442}
# {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.5959}
# {'neg': 0.0, 'neu': 0.834, 'pos': 0.166, 'compound': 0.3802}
# {'neg': 0.194, 'neu': 0.806, 'pos': 0.0, 'compound': -0.5574}
# {'neg': 0.381, 'neu': 0.619, 'pos': 0.0, 'compound': -0.85}
# {'neg': 0.228, 'neu': 0.607, 'pos': 0.165, 'compound': -0.1847}
# {'neg': 0.256, 'neu': 0.587, 'pos': 0.157, 'compound': -0.4927}
# {'neg': 0.0, 'neu': 0.429, 'pos': 0.571, 'compound': 0.8402}
# {'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.6115}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.151, 'neu': 0.676, 'pos': 0.174, 'compound': 0.1129}
# {'neg': 0.257, 'neu': 0.743, 'pos': 0.0, 'compound': -0.4158}
# {'neg': 0.24, 'neu': 0.76, 'pos': 0.0, 'compound': -0.6249}
# {'neg': 0.175, 'neu': 0.711, 'pos': 0.115, 'compound': -0.2714}
# {'neg': 0.213, 'neu': 0.516, 'pos': 0.271, 'compound': 0.2263}
# {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.153, 'neu': 0.847, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.36, 'neu': 0.543, 'pos': 0.097, 'compound': -0.7783}
# {'neg': 0.137, 'neu': 0.711, 'pos': 0.152, 'compound': 0.079}
# {'neg': 0.115, 'neu': 0.816, 'pos': 0.069, 'compound': -0.3182}
# {'neg': 0.118, 'neu': 0.695, 'pos': 0.187, 'compound': 0.3182}
# {'neg': 0.5, 'neu': 0.366, 'pos': 0.134, 'compound': -0.7901}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.081, 'neu': 0.772, 'pos': 0.147, 'compound': 0.4019}
# {'neg': 0.12, 'neu': 0.579, 'pos': 0.302, 'compound': 0.5267}
# {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.25}
# {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.5574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.193, 'neu': 0.528, 'pos': 0.279, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.7959}
# {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.6, 'pos': 0.4, 'compound': 0.25}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.06, 'neu': 0.94, 'pos': 0.0, 'compound': -0.1531}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'compound': 0.7256}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'compound': 0.5994}
# {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.541}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.25}
# {'neg': 0.113, 'neu': 0.753, 'pos': 0.134, 'compound': 0.128}
# {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.2023}
# {'neg': 0.0, 'neu': 0.653, 'pos': 0.347, 'compound': 0.8176}
# {'neg': 0.0, 'neu': 0.496, 'pos': 0.504, 'compound': 0.9453}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.584, 'pos': 0.416, 'compound': 0.6908}
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.8074}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.4284}
# {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.6124}
# {'neg': 0.103, 'neu': 0.776, 'pos': 0.121, 'compound': 0.1027}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'compound': 0.6808}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.098, 'neu': 0.902, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.101, 'neu': 0.769, 'pos': 0.13, 'compound': 0.1779}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.296}
# {'neg': 0.068, 'neu': 0.847, 'pos': 0.085, 'compound': 0.1027}
# {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.6239}
# {'neg': 0.285, 'neu': 0.715, 'pos': 0.0, 'compound': -0.4184}
# {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.7003}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.858, 'pos': 0.142, 'compound': 0.5106}
# {'neg': 0.221, 'neu': 0.779, 'pos': 0.0, 'compound': -0.6868}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.767, 'pos': 0.233, 'compound': 0.6679}
# {'neg': 0.0, 'neu': 0.81, 'pos': 0.19, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.636, 'pos': 0.364, 'compound': 0.8516}
# {'neg': 0.0, 'neu': 0.675, 'pos': 0.325, 'compound': 0.7717}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'compound': 0.5}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.7506}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.653, 'pos': 0.347, 'compound': 0.7482}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'compound': 0.7178}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.6801}
# {'neg': 0.212, 'neu': 0.788, 'pos': 0.0, 'compound': -0.6259}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.7073}
# {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.712, 'pos': 0.288, 'compound': 0.7717}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.849, 'pos': 0.151, 'compound': 0.3591}
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.8189}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'compound': 0.481}
# {'neg': 0.087, 'neu': 0.913, 'pos': 0.0, 'compound': -0.2732}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.07, 'neu': 0.93, 'pos': 0.0, 'compound': -0.1298}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.225, 'neu': 0.775, 'pos': 0.0, 'compound': -0.4404}
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.7125}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.112, 'neu': 0.888, 'pos': 0.0, 'compound': -0.3412}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.261, 'neu': 0.739, 'pos': 0.0, 'compound': -0.6808}
# {'neg': 0.191, 'neu': 0.556, 'pos': 0.254, 'compound': 0.2006}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.4753}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.3578}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.4466}
# {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.4926}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'compound': 0.3802}
# {'neg': 0.168, 'neu': 0.447, 'pos': 0.385, 'compound': 0.7422}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.5411}
# {'neg': 0.075, 'neu': 0.71, 'pos': 0.215, 'compound': 0.5162}
# {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.5216}
# {'neg': 0.149, 'neu': 0.851, 'pos': 0.0, 'compound': -0.2732}
# {'neg': 0.0, 'neu': 0.53, 'pos': 0.47, 'compound': 0.8916}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.28, 'neu': 0.72, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.362, 'neu': 0.638, 'pos': 0.0, 'compound': -0.6249}
# {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.4927}
# {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.8104}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.244, 'neu': 0.703, 'pos': 0.054, 'compound': -0.6814}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.6, 'pos': 0.4, 'compound': 0.25}
# {'neg': 0.214, 'neu': 0.786, 'pos': 0.0, 'compound': -0.4588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.4767}
# {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.121, 'neu': 0.714, 'pos': 0.165, 'compound': 0.2023}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.253, 'neu': 0.747, 'pos': 0.0, 'compound': -0.5256}
# {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.6908}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.81, 'pos': 0.19, 'compound': 0.6103}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.19, 'neu': 0.699, 'pos': 0.112, 'compound': -0.2789}
# {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.6801}
# {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.5502}
# {'neg': 0.0, 'neu': 0.899, 'pos': 0.101, 'compound': 0.2023}
# {'neg': 0.0, 'neu': 0.553, 'pos': 0.447, 'compound': 0.836}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.296, 'neu': 0.704, 'pos': 0.0, 'compound': -0.5216}
# {'neg': 0.0, 'neu': 0.9, 'pos': 0.1, 'compound': 0.2732}
# {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.3802}
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.7003}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.065, 'neu': 0.65, 'pos': 0.285, 'compound': 0.577}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.2003}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.128, 'neu': 0.872, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.6705}
# {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.7506}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.867}
# {'neg': 0.0, 'neu': 0.64, 'pos': 0.36, 'compound': 0.5423}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.2732}
# {'neg': 0.162, 'neu': 0.838, 'pos': 0.0, 'compound': -0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.084, 'neu': 0.766, 'pos': 0.149, 'compound': 0.1779}
# {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'compound': 0.7088}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'compound': 0.7717}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.271, 'neu': 0.729, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.174, 'neu': 0.826, 'pos': 0.0, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.2382}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'compound': -0.6608}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.2714}
# {'neg': 0.13, 'neu': 0.753, 'pos': 0.117, 'compound': -0.0772}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.3182}
# {'neg': 0.398, 'neu': 0.448, 'pos': 0.154, 'compound': -0.5994}
# {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'compound': 0.128}
# {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.152, 'neu': 0.707, 'pos': 0.141, 'compound': 0.1779}
# {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ...
# {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.636}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.711, 'pos': 0.289, 'compound': 0.6908}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'compound': 0.8858}
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.1531}
# {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.4926}
# {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.5849}
# {'neg': 0.151, 'neu': 0.566, 'pos': 0.283, 'compound': 0.4753}
# {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.7418}
# {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'compound': 0.7579}
# {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.6369}
# {'neg': 0.075, 'neu': 0.925, 'pos': 0.0, 'compound': -0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 0.564, 'pos': 0.436, 'compound': 0.7339}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.6514}
# {'neg': 0.0, 'neu': 0.636, 'pos': 0.364, 'compound': 0.8834}
# {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.6588}
# {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'compound': 0.8316}
# {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.765}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.246, 'neu': 0.492, 'pos': 0.262, 'compound': 0.0516}
# {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.6588}
# {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.6239}
# {'neg': 0.379, 'neu': 0.621, 'pos': 0.0, 'compound': -0.7269}
# {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'compound': 0.7097}
# {'neg': 0.0, 'neu': 0.497, 'pos': 0.503, 'compound': 0.9033}
# {'neg': 0.094, 'neu': 0.356, 'pos': 0.55, 'compound': 0.9155}
# {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.6908}
# {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.8074}
# {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.5859}
# {'neg': 0.322, 'neu': 0.457, 'pos': 0.221, 'compound': -0.3254}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.8016}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.7096}
# {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.555}
# {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.572, 'pos': 0.428, 'compound': 0.8999}
# {'neg': 0.162, 'neu': 0.586, 'pos': 0.252, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'compound': -0.3802}
# {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.7405}
# {'neg': 0.0, 'neu': 0.611, 'pos': 0.389, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.802}
# {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'compound': 0.765}
# {'neg': 0.0, 'neu': 0.691, 'pos': 0.309, 'compound': 0.8001}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.6124}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.2263}
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.7906}
# {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4003}
# {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'compound': 0.6688}
# {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'compound': 0.7717}
# {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.095, 'neu': 0.589, 'pos': 0.315, 'compound': 0.833}
# {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'compound': 0.872}
# {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.6114}
# {'neg': 0.0, 'neu': 0.437, 'pos': 0.563, 'compound': 0.9168}
# {'neg': 0.084, 'neu': 0.769, 'pos': 0.147, 'compound': 0.4203}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.7901}
# {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.5255}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.115, 'neu': 0.556, 'pos': 0.329, 'compound': 0.6124}
# {'neg': 0.397, 'neu': 0.603, 'pos': 0.0, 'compound': -0.5096}
# {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.8932}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.7, 'pos': 0.3, 'compound': 0.8458}
# {'neg': 0.0, 'neu': 0.589, 'pos': 0.411, 'compound': 0.636}
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.3612}
# {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.6, 'pos': 0.4, 'compound': 0.7177}
# {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.855}
# {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.2732}
# {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.6249}
# {'neg': 0.094, 'neu': 0.561, 'pos': 0.345, 'compound': 0.7023}
# {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.5859}
# {'neg': 0.119, 'neu': 0.681, 'pos': 0.2, 'compound': 0.2263}
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.5574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'compound': 0.8677}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.5106}
# {'neg': 0.08, 'neu': 0.798, 'pos': 0.122, 'compound': 0.2023}
# {'neg': 0.0, 'neu': 0.406, 'pos': 0.594, 'compound': 0.6588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.151, 'neu': 0.603, 'pos': 0.246, 'compound': 0.3786}
# {'neg': 0.0, 'neu': 0.642, 'pos': 0.358, 'compound': 0.7713}
# {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.559, 'pos': 0.441, 'compound': 0.7832}
# {'neg': 0.0, 'neu': 0.64, 'pos': 0.36, 'compound': 0.7237}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.6988}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.6124}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.348, 'neu': 0.506, 'pos': 0.146, 'compound': -0.5574}
# {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 0.562, 'pos': 0.438, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.5848}
# {'neg': 0.201, 'neu': 0.714, 'pos': 0.084, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.4404}
# {'neg': 0.062, 'neu': 0.594, 'pos': 0.343, 'compound': 0.8876}
# {'neg': 0.0, 'neu': 0.602, 'pos': 0.398, 'compound': 0.765}
# {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.6155}
# {'neg': 0.076, 'neu': 0.732, 'pos': 0.192, 'compound': 0.5684}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.121, 'neu': 0.823, 'pos': 0.056, 'compound': -0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.5093}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.353, 'pos': 0.647, 'compound': 0.8798}
# {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'compound': 0.6476}
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.7096}
# {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.581, 'pos': 0.419, 'compound': 0.855}
# {'neg': 0.0, 'neu': 0.53, 'pos': 0.47, 'compound': 0.7351}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.849, 'pos': 0.151, 'compound': 0.4926}
# {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.6588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.7906}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.6666}
# {'neg': 0.086, 'neu': 0.679, 'pos': 0.235, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.17, 'neu': 0.516, 'pos': 0.314, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.849, 'pos': 0.151, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'compound': 0.5848}
# {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.5859}
# {'neg': 0.131, 'neu': 0.733, 'pos': 0.136, 'compound': 0.0258}
# {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.4926}
# {'neg': 0.077, 'neu': 0.648, 'pos': 0.275, 'compound': 0.7074}
# {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.6249}
# {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.1027}
# {'neg': 0.0, 'neu': 0.801, 'pos': 0.199, 'compound': 0.4549}
# {'neg': 0.119, 'neu': 0.748, 'pos': 0.133, 'compound': 0.0697}
# {'neg': 0.259, 'neu': 0.741, 'pos': 0.0, 'compound': -0.4199}
# {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.6, 'pos': 0.4, 'compound': 0.8999}
# {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'compound': 0.2263}
# {'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'compound': 0.6705}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.336, 'neu': 0.664, 'pos': 0.0, 'compound': -0.7269}
# {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.3804}
# {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'compound': 0.8858}
# {'neg': 0.097, 'neu': 0.76, 'pos': 0.143, 'compound': 0.2698}
# {'neg': 0.0, 'neu': 0.462, 'pos': 0.538, 'compound': 0.7893}
# {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'compound': 0.7845}
# {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.4005}
# {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 0.586, 'pos': 0.414, 'compound': 0.9186}
# {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.7339}
# {'neg': 0.0, 'neu': 0.587, 'pos': 0.413, 'compound': 0.8705}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.4926}
# {'neg': 0.047, 'neu': 0.65, 'pos': 0.303, 'compound': 0.8353}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.25, 'pos': 0.75, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.617, 'pos': 0.383, 'compound': 0.8519}
# {'neg': 0.0, 'neu': 0.524, 'pos': 0.476, 'compound': 0.6739}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.7352}
# {'neg': 0.08, 'neu': 0.804, 'pos': 0.116, 'compound': 0.2449}
# {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.484}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.462, 'pos': 0.538, 'compound': 0.9461}
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}
# {'neg': 0.183, 'neu': 0.657, 'pos': 0.16, 'compound': -0.128}
# {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.2263}
# {'neg': 0.236, 'neu': 0.621, 'pos': 0.143, 'compound': -0.3595}
# {'neg': 0.13, 'neu': 0.622, 'pos': 0.248, 'compound': 0.508}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.6588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'compound': 0.7345}
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.825}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.431, 'pos': 0.569, 'compound': 0.8491}
# {'neg': 0.295, 'neu': 0.446, 'pos': 0.259, 'compound': -0.1027}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6369}
# {'neg': 0.139, 'neu': 0.861, 'pos': 0.0, 'compound': -0.5267}
# {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.7405}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.6486}
# {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404}
# {'neg': 0.23, 'neu': 0.77, 'pos': 0.0, 'compound': -0.5562}
# {'neg': 0.084, 'neu': 0.837, 'pos': 0.079, 'compound': -0.0258}
# {'neg': 0.0, 'neu': 0.681, 'pos': 0.319, 'compound': 0.8176}
# {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.2023}
# {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772}
# {'neg': 0.188, 'neu': 0.812, 'pos': 0.0, 'compound': -0.4184}
# {'neg': 0.482, 'neu': 0.353, 'pos': 0.165, 'compound': -0.7506}
# {'neg': 0.204, 'neu': 0.796, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 0.365, 'pos': 0.635, 'compound': 0.5399}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.5093}
# {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.6124}

# %% [markdown]
# ### 4.1.3. Now let's compare both tools

# %%
def analyze_text(input_text, analyzer):
    # define analyzer
    if analyzer == 'textblob':
        score = TextBlob(input_text).sentiment.polarity
    elif analyzer == 'vader':
        result = vds.polarity_scores(input_text)
        score = result['compound']
    
    # define scores 
    if score > 0:   # positive
        result = 1
    elif score < 0: # negative
        result = -1
    else:           # neutral/irrelevant
        result = 0
    return result

# %%
df_compare = corpus[['TweetText','label']].copy()
df_compare['blob_sentiment'] = df_compare['TweetText'].apply(analyze_text, analyzer='textblob')
df_compare['vader_sentiment'] = df_compare['TweetText'].apply(analyze_text, analyzer='vader')
df_compare.head()
# Out:
#                                              TweetText  label  blob_sentiment  \
# 519  Wtf is a tweet , sounds like tha dam cartoon n...     -1              -1
# 520  #DontBeMadAtMeBecause #Android is by far bette...     -1               1
# 521  I really hate dealing with the brain dead peop...     -1              -1
# 522  Reader 'Tronman' compares #SteveBallmer to an ...     -1               0
# 523  #Twitter.... Side Affects include: Procrastina...     -1              -1
#
#      vader_sentiment
# 519               -1
# 520                1
# 521               -1
# 522                1
# 523               -1

# %%
# calculate confusion matrix
import numpy as np
from sklearn.metrics import confusion_matrix

vader = confusion_matrix(df_compare['label'], df_compare['vader_sentiment'], \
                                          labels=[-1,0,1])

blob = confusion_matrix(df_compare['label'], df_compare['blob_sentiment'], \
                                  labels=[-1,0,1])


vader = pd.DataFrame(vader, columns = ['pred_negative', 'pred_neutral', 'pred_positive'], \
                     index=['true_negative','true_neutral','true_positive'])

blob = pd.DataFrame(blob, columns = ['pred_negative', 'pred_neutral', 'pred_positive'], \
                     index=['true_negative','true_neutral','true_positive'])

# %% [markdown]
# As we can see in the **VADER** confusion matrix with the diagonal results, the accuracy, also shown in the classification report, resulted in 0.58. We also have a higher precision (TP/TP+FP) for negative sentiment i.e. less false positives; and a higher recall (TP/TP+FN) for the positive sentiment i.e. less false negatives.

# %%
vader
# Out:
#                pred_negative  pred_neutral  pred_positive
# true_negative            268           123            128
# true_neutral              61           266            192
# true_positive             49            96            374

# %%
from sklearn.metrics import classification_report

print(classification_report(df_compare['label'], df_compare['vader_sentiment'], \
                                          target_names=['negative','neutral','positive']))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.52      0.60       519
#      neutral       0.55      0.51      0.53       519
#     positive       0.54      0.72      0.62       519
#
#     accuracy                           0.58      1557
#    macro avg       0.60      0.58      0.58      1557
# weighted avg       0.60      0.58      0.58      1557

# %% [markdown]
# As we can see in the **Blob** confusion matrix with the diagonal results, the accuracy, also shown in the classification report, resulted in 0.55, less than *VADER*, but the precision and recall values followed the same trend.
#
# These values, especially for accuracy, are quite low. One way to try to reverse this would be changing the scores for binary excluding neutral i.e. > 0 - positive, else negative

# %%
blob
# Out:
#                pred_negative  pred_neutral  pred_positive
# true_negative            217           154            148
# true_neutral              44           275            200
# true_positive             38           124            357

# %%
print(classification_report(df_compare['label'], df_compare['blob_sentiment'], \
                                          target_names=['negative','neutral','positive']))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.42      0.53       519
#      neutral       0.50      0.53      0.51       519
#     positive       0.51      0.69      0.58       519
#
#     accuracy                           0.55      1557
#    macro avg       0.58      0.55      0.54      1557
# weighted avg       0.58      0.55      0.54      1557

# %% [markdown]
# ## 4.2. Modeling
#
# To predict the tweets' sentiment we'll different algorithms, some applying the labeled corpus as training set, and some with 'undirected' labeling (VADER & TextBlob):
#
# 1. Multinomial Naïve Bayes
# 2. Support Vector Machines
# 3. Vader
# 4. TextBlob
#
# The last two were explained before. The first ones will be explained here.

# %%
# split the model
X_train = corpus['TweetText']
X_test = tweets['text']
y_train = corpus['label']

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((1557,), (1557,), (1174,))

# %% [markdown]
# ### 4.2.1. Count Vectorizer
#
# In order to use textual data for predictive modeling, the text must be parsed to remove certain words – this process is called tokenization. These words need to then be encoded as integers, or floating-point values, for use as inputs in machine learning algorithms. This process is called feature extraction (or vectorization) [[9]](https://www.educative.io/edpresso/countvectorizer-in-python).
#
# CountVectorizer is used to convert a collection of text documents to a vector of term/token counts, and also enables the pre-processing of text data prior to generating the vector representation [[10]](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html).

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
vectorizer = CountVectorizer(ngram_range=(1,3), min_df=1)
X_train_vec = vectorizer.fit_transform(X_train)

mdl = MultinomialNB(alpha=0.1).fit(X_train_vec, y_train)

y_pred_NB_count = mdl.predict(vectorizer.transform(X_test))

mdl.score(X_train_vec, y_train)
# Out:
# 0.9974309569685292

# %%
count_score = np.asarray(X_train_vec.mean(axis=0)).ravel().tolist()
count_weights = pd.DataFrame({'term': vectorizer.get_feature_names(), 'weight': vect_score})
count_weights.sort_values(by='weight',ascending=False,inplace=True)

# %%
from sklearn.svm import SVC

mdl = SVC(C=10000).fit(X_train_vec, y_train).fit(X_train_vec, y_train)

y_pred_SVM_count = mdl.predict(vectorizer.transform(X_test))

mdl.score(X_train_vec, y_train)
# Out:
# 1.0

# %% [markdown]
# ### 4.2.2. Term-Frequency - Inverse-Document-Frequency (Tf-Idf)
#
# TfidfVectorizer that combines all the options of CountVectorizer and TfidfTransformer in a single model i.e. it counts the tokens and apply the Term Frequency Inverse Document Frequency normalization to a sparse matrix of occurrence counts [[11]](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,3), min_df=1)

X_train_vec = vectorizer.fit_transform(X_train)

mdl = MultinomialNB(alpha=0.1).fit(X_train_vec, y_train)

y_pred_NB_tfidf = mdl.predict(vectorizer.transform(X_test))

mdl.score(X_train_vec, y_train)
# Out:
# 0.9980732177263969

# %%
tfidf_score = np.asarray(X_train_vec.mean(axis=0)).ravel().tolist()
tfidf_weights = pd.DataFrame({'term': vectorizer.get_feature_names(), 'weight': vect_score})
tfidf_weights.sort_values(by='weight',ascending=False,inplace=True)

# %%
mdl = SVC(C=10000).fit(X_train_vec, y_train).fit(X_train_vec, y_train)

y_pred_SVM_tfidf = mdl.predict(vectorizer.transform(X_test))

mdl.score(X_train_vec, y_train)
# Out:
# 1.0

# %% [markdown]
# ## 4.3. Compare Results

# %%
blob_sentiment = X_test.apply(analyze_text, analyzer='textblob')
vader_sentiment = X_test.apply(analyze_text, analyzer='vader')

# %%
y_pred_NB_count.shape, y_pred_NB_tfidf.shape, y_pred_SVM_count.shape, y_pred_SVM_tfidf.shape, \
blob_sentiment.shape, vader_sentiment.shape
# Out:
# ((1174,), (1174,), (1174,), (1174,), (1174,), (1174,))

# %%
# fecth positive, neutral, and negative results
# for Naïve Bayes + CountVect
unique, counts = np.unique(y_pred_NB_count, return_counts=True)
NB_count = dict(zip(unique, counts))

# for Naïve Bayes + TfIdf
unique, counts = np.unique(y_pred_NB_tfidf, return_counts=True)
NB_tfidf = dict(zip(unique, counts))

# for SVM + CountVect
unique, counts = np.unique(y_pred_SVM_count, return_counts=True)
SVM_count = dict(zip(unique, counts))

# for SVM + TfIdf
unique, counts = np.unique(y_pred_SVM_tfidf, return_counts=True)
SVM_tfidf = dict(zip(unique, counts))

# for TextBlob
unique, counts = np.unique(blob_sentiment, return_counts=True)
blob = dict(zip(unique, counts))

# for VADER
unique, counts = np.unique(vader_sentiment, return_counts=True)
vader = dict(zip(unique, counts))

# %% [markdown]
# Comparing the results, we can see the values had a **high variance** over labels, especially for SVM. As we can see above, the score results for the training set for this algorithm resulted in 1, which can be potentitally overfitted. A possibility to reduce this values (same for NB, which can be overfitting too) is to implement ngrams and use higher min_df (minimum frequency in document), both set to the lower limits.

# %%
compare = pd.DataFrame([NB_count, SVM_count, NB_tfidf, SVM_tfidf, blob, vader],
                      index=['NB_count', 'SVM_count', 'NB_tfidf', 'SVM_tfidf', 'blob', 'vader'])
compare.columns=['negative', 'neutral', 'positive']
compare
# Out:
#            negative  neutral  positive
# NB_count        626      205       343
# SVM_count       258      136       780
# NB_tfidf        649      160       365
# SVM_tfidf       803      222       149
# blob            313      441       420
# vader           535      323       316

# %%
# comparing the weights for Countvec & TfIdfVec we see that the words with largest and 
# lowest weights are the same for both
count_weights[:5]
# Out:
#           term    weight
# 2680     apple  0.019865
# 12734   google  0.017847
# 31071      the  0.017575
# 33809  twitter  0.017393
# 14567     http  0.016944

# %%
tfidf_weights[:5]
# Out:
#           term    weight
# 2680     apple  0.019865
# 12734   google  0.017847
# 31071      the  0.017575
# 33809  twitter  0.017393
# 14567     http  0.016944

# %%
count_weights[-5:]
# Out:
#                    term    weight
# 15130      hut nfl wish  0.000074
# 15129           hut nfl  0.000074
# 15128       hut hut nfl  0.000074
# 15127           hut hut  0.000074
# 7032   co j2ftieng ipad  0.000074

# %%
tfidf_weights[-5:]
# Out:
#                    term    weight
# 15130      hut nfl wish  0.000074
# 15129           hut nfl  0.000074
# 15128       hut hut nfl  0.000074
# 15127           hut hut  0.000074
# 7032   co j2ftieng ipad  0.000074
